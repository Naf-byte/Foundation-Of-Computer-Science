# %%
from pathlib import Path
import pandas as pd

# Folder where all your CSVs are stored
data_path = Path("../data")

# Get all CSV files
csv_files = sorted(data_path.glob("*.csv"))  # sorted just to keep order consistent

# %%
csv_files
# Out:
# [WindowsPath('../data/CAvideos.csv'),
#  WindowsPath('../data/DEvideos.csv'),
#  WindowsPath('../data/FRvideos.csv'),
#  WindowsPath('../data/GBvideos.csv'),
#  WindowsPath('../data/INvideos.csv'),
#  WindowsPath('../data/JPvideos.csv'),
#  WindowsPath('../data/KRvideos.csv'),
#  WindowsPath('../data/MXvideos.csv'),
#  WindowsPath('../data/RUvideos.csv'),
#  WindowsPath('../data/USvideos.csv')]

# %% [markdown]
# ## 1. Create a single dataframe with the concatenation of all input csv files, adding a column called country

# %%
pip install charset-normalizer
# Out:
# Requirement already satisfied: charset-normalizer in c:\users\lenovo\anaconda3\lib\site-packages (3.3.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
# dfs = []

# for file in csv_files:
#     print(f"Reading: {file.name}")
    
#     # Extract country code from filename, e.g. "USvideos.csv" -> "US"
#     country_code = file.stem[:2]
    
#     # Read CSV with a tolerant encoding
#     df_temp = pd.read_csv(file, encoding="latin1")  # <--- important change
    
#     # Add country column
#     df_temp["country"] = country_code
    
#     dfs.append(df_temp)

dfs = []

def convert_latin1_to_utf8(df):
    for col in df.select_dtypes(include="object").columns:
        try:
            df[col] = df[col].astype(str).apply(lambda x: x.encode("latin1").decode("utf-8"))
        except Exception:
            df[col] = df[col].astype(str).apply(
                lambda x: x.encode("latin1", errors="replace").decode("utf-8", errors="replace")
            )
    return df


for file in csv_files:
    print(f"\nReading: {file.name}")
    
    country_code = file.stem[:2]

    # Read using Latin-1
    df_temp = pd.read_csv(file, encoding="latin1", dtype=str)

    # Convert strings Latin-1 → UTF-8
    df_temp = convert_latin1_to_utf8(df_temp)

    # 🔥 Convert numeric columns BACK to numbers
    numeric_cols = ["views", "likes", "dislikes", "comment_count"]
    for col in numeric_cols:
        if col in df_temp.columns:
            df_temp[col] = pd.to_numeric(df_temp[col], errors="coerce")

    df_temp["country"] = country_code
    dfs.append(df_temp)

df = pd.concat(dfs, ignore_index=True)
# Out:
# Reading: CAvideos.csv
#
# Reading: DEvideos.csv
#
# Reading: FRvideos.csv
#
# Reading: GBvideos.csv
#
# Reading: INvideos.csv
#
# Reading: JPvideos.csv
#
# Reading: KRvideos.csv
#
# Reading: MXvideos.csv
#
# Reading: RUvideos.csv
#
# Reading: USvideos.csv

# %%
# Concatenate all dataframes into one
df = pd.concat(dfs, ignore_index=True)

print("Final combined shape:", df.shape)
df.head()
# Out:
# Final combined shape: (375942, 17)
#       video_id trending_date  \
# 0  n1WpP7iowLc      17.14.11
# 1  0dBIkQ4Mz1M      17.14.11
# 2  5qpjK5DgCt4      17.14.11
# 3  d380meD0W0M      17.14.11
# 4  2Vv-BfVoq4g      17.14.11
#
#                                                title channel_title  \
# 0         Eminem - Walk On Water (Audio) ft. Beyoncé    EminemVEVO
# 1                      PLUSH - Bad Unboxing Fan Mail     iDubbbzTV
# 2  Racist Superman | Rudy Mancuso, King Bach & Le...  Rudy Mancuso
# 3                           I Dare You: GOING BALD!?      nigahiga
# 4        Ed Sheeran - Perfect (Official Music Video)    Ed Sheeran
#
#   category_id              publish_time  \
# 0          10  2017-11-10T17:00:03.000Z
# 1          23  2017-11-13T17:00:00.000Z
# 2          23  2017-11-12T19:05:24.000Z
# 3          24  2017-11-12T18:01:41.000Z
# 4          10  2017-11-09T11:04:14.000Z
#
#                                                 tags     views    likes  \
# 0  Eminem|"Walk"|"On"|"Water"|"Aftermath/Shady/In...  17158579   787425
# 1  plush|"bad unboxing"|"unboxing"|"fan mail"|"id...   1014651   127794
# 2  racist superman|"rudy"|"mancuso"|"king"|"bach"...   3191434   146035
# 3  ryan|"higa"|"higatv"|"nigahiga"|"i dare you"|"...   2095828   132239
# 4  edsheeran|"ed sheeran"|"acoustic"|"live"|"cove...  33523622  1634130
#
#    dislikes  comment_count                                  thumbnail_link  \
# 0     43420         125882  https://i.ytimg.com/vi/n1WpP7iowLc/default.jpg
# 1      1688          13030  https://i.ytimg.com/vi/0dBIkQ4Mz1M/default.jpg
# 2      5339           8181  https://i.ytimg.com/vi/5qpjK5DgCt4/default.jpg
# 3      1989          17518  https://i.ytimg.com/vi/d380meD0W0M/default.jpg
# 4     21082          85067  https://i.ytimg.com/vi/2Vv-BfVoq4g/default.jpg
#
#   comments_disabled ratings_disabled video_error_or_removed  \
# 0             False            False                  False
# 1             False            False                  False
# 2             False            False                  False
# 3             False            False                  False
# 4             False            False                  False
#
#                                          description country
# 0  Eminem's new track Walk on Water ft. Beyoncé i...      CA
# 1  STill got a lot of packages. Probably will las...      CA
# 2  WATCH MY PREVIOUS VIDEO ▶ \n\nSUBSCRIBE ► http...      CA
# 3  I know it's been a while since we did this sho...      CA
# 4  🎧: https://ad.gt/yt-perfect\n💰: https://atlant...      CA

# %%
# df_us = pd.read_csv("../data/USvideos.csv")
# df_us.head()
df_us = pd.read_csv("../data/CAvideos.csv", encoding="utf-8")
df_us.head(100)
# Out:
#        video_id trending_date  \
# 0   n1WpP7iowLc      17.14.11
# 1   0dBIkQ4Mz1M      17.14.11
# 2   5qpjK5DgCt4      17.14.11
# 3   d380meD0W0M      17.14.11
# 4   2Vv-BfVoq4g      17.14.11
# ..          ...           ...
# 95  zxuvr9tN924      17.14.11
# 96  dKBThyjj0J0      17.14.11
# 97  pQgPR2V6924      17.14.11
# 98  lHcXhBojpeQ      17.14.11
# 99  Yo84eqYwP98      17.14.11
#
#                                                 title  \
# 0          Eminem - Walk On Water (Audio) ft. Beyoncé
# 1                       PLUSH - Bad Unboxing Fan Mail
# 2   Racist Superman | Rudy Mancuso, King Bach & Le...
# 3                            I Dare You: GOING BALD!?
# 4         Ed Sheeran - Perfect (Official Music Video)
# ..                                                ...
# 95       非诚勿扰 完整版 “小朱亚文”亮相《非诚勿扰》 孟非上演cosplay首秀 171111
# 96  'Helping People' Sneak Peek Ep. 805 | The Walk...
# 97  《文茜世界周報》美媒狂酸川普　對華貿易選前選後判若兩人2017.11.11|Sisy's W...
# 98                   三屆TVB視帝，拋棄10年青梅竹馬髮妻，為娶小三還不惜與母絕交！
# 99  LA PIRE PARTIE ft Le Rire Jaune, Pierre Croce,...
#
#                                channel_title  category_id  \
# 0                                 EminemVEVO           10
# 1                                  iDubbbzTV           23
# 2                               Rudy Mancuso           23
# 3                                   nigahiga           24
# 4                                 Ed Sheeran           10
# ..                                       ...          ...
# 95  江苏卫视官方频道China JiangsuTV Official Channel           24
# 96                                       amc           24
# 97                 文茜的世界周報 Sisy's World News           25
# 98                                     明星百曉生           22
# 99                                   Le Labo           24
#
#                 publish_time  \
# 0   2017-11-10T17:00:03.000Z
# 1   2017-11-13T17:00:00.000Z
# 2   2017-11-12T19:05:24.000Z
# 3   2017-11-12T18:01:41.000Z
# 4   2017-11-09T11:04:14.000Z
# ..                       ...
# 95  2017-11-11T16:00:04.000Z
# 96  2017-11-13T03:00:01.000Z
# 97  2017-11-12T07:09:51.000Z
# 98  2017-11-12T12:49:50.000Z
# 99  2017-11-12T15:00:02.000Z
#
#                                                  tags     views    likes  \
# 0   Eminem|"Walk"|"On"|"Water"|"Aftermath/Shady/In...  17158579   787425
# 1   plush|"bad unboxing"|"unboxing"|"fan mail"|"id...   1014651   127794
# 2   racist superman|"rudy"|"mancuso"|"king"|"bach"...   3191434   146035
# 3   ryan|"higa"|"higatv"|"nigahiga"|"i dare you"|"...   2095828   132239
# 4   edsheeran|"ed sheeran"|"acoustic"|"live"|"cove...  33523622  1634130
# ..                                                ...       ...      ...
# 95  江苏卫视|"非诚勿扰"|"姜振宇"|"孟非"|"黄澜"|"黄菡"|"黄磊"|"相亲"|"交友...    150974      220
# 96  The Walking Dead|"episode 805"|"episode 5"|"Th...     70448     1538
# 97  陳文茜|"文茜世界周報"|"文茜世界財經週報"|"中天的夢想驛站"|"Courier Sta...    135620      379
# 98                                             [none]     88061       47
# 99                                             [none]    432721    14053
#
#     dislikes  comment_count                                  thumbnail_link  \
# 0      43420         125882  https://i.ytimg.com/vi/n1WpP7iowLc/default.jpg
# 1       1688          13030  https://i.ytimg.com/vi/0dBIkQ4Mz1M/default.jpg
# 2       5339           8181  https://i.ytimg.com/vi/5qpjK5DgCt4/default.jpg
# 3       1989          17518  https://i.ytimg.com/vi/d380meD0W0M/default.jpg
# 4      21082          85067  https://i.ytimg.com/vi/2Vv-BfVoq4g/default.jpg
# ..       ...            ...                                             ...
# 95        65            201  https://i.ytimg.com/vi/zxuvr9tN924/default.jpg
# 96        25            315  https://i.ytimg.com/vi/dKBThyjj0J0/default.jpg
# 97        86            449  https://i.ytimg.com/vi/pQgPR2V6924/default.jpg
# 98        58             17  https://i.ytimg.com/vi/lHcXhBojpeQ/default.jpg
# 99       576           1161  https://i.ytimg.com/vi/Yo84eqYwP98/default.jpg
#
#     comments_disabled  ratings_disabled  video_error_or_removed  \
# 0               False             False                   False
# 1               False             False                   False
# 2               False             False                   False
# 3               False             False                   False
# 4               False             False                   False
# ..                ...               ...                     ...
# 95              False             False                   False
# 96              False             False                   False
# 97              False             False                   False
# 98              False             False                   False
# 99              False             False                   False
#
#                                           description
# 0   Eminem's new track Walk on Water ft. Beyoncé i...
# 1   STill got a lot of packages. Probably will las...
# 2   WATCH MY PREVIOUS VIDEO ▶ \n\nSUBSCRIBE ► http...
# 3   I know it's been a while since we did this sho...
# 4   🎧: https://ad.gt/yt-perfect\n💰: https://atlant...
# ..                                                ...
# 95  关注【微信公众号】最新独家内容抢先看！\n江苏卫视官方微信“JSBC-JSTV”\n非诚勿扰...
# 96  Negan and Father Gabriel remain trapped togeth...
# 97  《中天的夢想驛站》更多影音→https://goo.gl/BbhRZJ\n《文茜的世界週報》...
# 98                                                NaN
# 99  Le jeu de société: https://goo.gl/hhG1Ta\n\nGa...
#
# [100 rows x 16 columns]

# %% [markdown]
# # 2. Extract all videos that have no tag.

# %%
no_tag_videos = df[
    df['tags'].isna() |
    (df['tags'].str.lower().isin(["[none]", "[]"])) |
    (df['tags'].str.strip() == "") |
    (df['tags'] == "No tags")
]

no_tag_videos.head()
# Out:
#        video_id trending_date  \
# 41  JwboxqDylgg      17.14.11
# 58  9B-q8h31Bpk      17.14.11
# 78  1UE5Dq1rvUA      17.14.11
# 86  pmJQ4KwliX4      17.14.11
# 98  lHcXhBojpeQ      17.14.11
#
#                                                 title  channel_title  \
# 41  Canada Soccer's Women's National Team v USA In...  Canada Soccer
# 58  John Oliver Tackles Louis C.K. And Donald Trum...       TV Shows
# 78            Taylor Swift Perform Ready For It - SNL     Ken Reactz
# 86  LATEST Q POSTS: ROTHSCHILDS, HOUSE OF SAUD, lL...   James Munder
# 98                   三屆TVB視帝，拋棄10年青梅竹馬髮妻，為娶小三還不惜與母絕交！          明星百曉生
#
#    category_id              publish_time    tags   views  likes  dislikes  \
# 41          17  2017-11-13T05:53:49.000Z  [none]   36311    277        28
# 58          22  2017-11-13T04:49:26.000Z  [none]  106029   1270       101
# 78          24  2017-11-12T05:18:02.000Z  [none]  320964   8069       285
# 86           2  2017-11-12T21:25:40.000Z  [none]  116820   1503       139
# 98          22  2017-11-12T12:49:50.000Z  [none]   88061     47        58
#
#     comment_count                                  thumbnail_link  \
# 41             13  https://i.ytimg.com/vi/JwboxqDylgg/default.jpg
# 58            181  https://i.ytimg.com/vi/9B-q8h31Bpk/default.jpg
# 78            717  https://i.ytimg.com/vi/1UE5Dq1rvUA/default.jpg
# 86           1066  https://i.ytimg.com/vi/pmJQ4KwliX4/default.jpg
# 98             17  https://i.ytimg.com/vi/lHcXhBojpeQ/default.jpg
#
#    comments_disabled ratings_disabled video_error_or_removed  \
# 41             False            False                  False
# 58             False            False                  False
# 78             False            False                  False
# 86             False            False                  False
# 98             False            False                  False
#
#                                           description country
# 41  Canada Soccer's Women's National Team face riv...      CA
# 58                  John Oliver on News, Politics ...      CA
# 78  Thanks for watching please subscribe and subsc...      CA
# 86  https://pastebin.ca/3930472\n\nSupport My Chan...      CA
# 98                                                nan      CA

# %% [markdown]
# # 3. For each channel, determine the total number of views

# %%
channel_views = df.groupby("channel_title")["views"].sum().reset_index()

channel_views.head()
# Out:
#             channel_title    views
# 0              ! 세상에 무슨일이  3942977
# 1           !!8時だよ面白ネタ大集合    50207
# 2          !BTS・TWICE まとめ     7310
# 3  !Los amorosos Virales¡     6069
# 4                 !t Live   240038

# %% [markdown]
# # 4. Save all rows with disabled comments and disabled ratings, or that have video_error_or_removed in a new dataframe called excluded, and remove those rows from the original dataframe.

# %%
# Task 4: Find rows to exclude
excluded = df[
    (df["comments_disabled"] == True) |
    (df["ratings_disabled"] == True) |
    (df["video_error_or_removed"] == True)
]

# Show how many rows are excluded
print("Excluded rows:", excluded.shape[0])

# Remove excluded rows from original dataframe
df = df.drop(excluded.index).reset_index(drop=True)

print("Remaining rows:", df.shape[0])
# Out:
# Excluded rows: 0
# Remaining rows: 375942

# %% [markdown]
# # 5. Add a like_ratio column storing the ratio between the number of likes and of dislikes

# %%
# Task 5: Add like_ratio column (likes / dislikes)

df["like_ratio"] = df["likes"] / df["dislikes"].replace(0, pd.NA)

df["like_ratio"].head()

# 🔍 Why replace(0, pd.NA)?
# Because if dislikes = 0, dividing by zero gives an error.
# pd.NA makes the ratio NaN instead of crashing.
# Out:
# 0    18.135076
# 1    75.707346
# 2      27.3525
# 3    66.485168
# 4    77.513044
# Name: like_ratio, dtype: object

# %% [markdown]
# # 6. Cluster the publish time into 10-minute intervals (e.g. from 02:20 to 02:30)

# %%
# Task 6: Convert publish_time to datetime (if not already)
df["publish_time"] = pd.to_datetime(df["publish_time"], errors="coerce")

# Create 10-minute interval column
df["publish_time_10min"] = df["publish_time"].dt.floor("10T")

df[["publish_time", "publish_time_10min"]].head()
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_12348\3123573461.py:5: FutureWarning: 'T' is deprecated and will be removed in a future version, please use 'min' instead.
#   df["publish_time_10min"] = df["publish_time"].dt.floor("10T")
#                publish_time        publish_time_10min
# 0 2017-11-10 17:00:03+00:00 2017-11-10 17:00:00+00:00
# 1 2017-11-13 17:00:00+00:00 2017-11-13 17:00:00+00:00
# 2 2017-11-12 19:05:24+00:00 2017-11-12 19:00:00+00:00
# 3 2017-11-12 18:01:41+00:00 2017-11-12 18:00:00+00:00
# 4 2017-11-09 11:04:14+00:00 2017-11-09 11:00:00+00:00

# %% [markdown]
# # 7. For each interval, determine the number of videos, average number of likes and of dislikes.

# %%
interval_stats = df.groupby("publish_time_10min").agg(
    videos_count = ("video_id", "count"), 
    avg_likes = ("likes", "mean"),
    avg_dislikes = ("dislikes", "mean")
).reset_index()

interval_stats.head()
# Out:
#          publish_time_10min  videos_count   avg_likes  avg_dislikes
# 0 2006-07-23 08:20:00+00:00             1  459.000000      152.0000
# 1 2007-03-05 16:20:00+00:00             9  336.666667        2.0000
# 2 2007-06-25 06:50:00+00:00            12  579.833333       11.5000
# 3 2007-12-03 20:50:00+00:00            16  187.937500       15.6875
# 4 2008-01-07 21:20:00+00:00            10   99.900000        2.0000

# %% [markdown]
# # 8. For each tag, determine the number of videos
# ## Notice that tags contains a string with several tags.

# %%
# Replace missing or invalid tags with empty string
df["tags"] = df["tags"].fillna("")

# Split tags by "|" and explode into separate rows
df_tags = df.assign(tag = df["tags"].str.split("|")).explode("tag")

# Remove empty tags (like "" or " ")
df_tags = df_tags[df_tags["tag"].str.strip() != ""]

# Count videos per tag
tag_counts = df_tags["tag"].value_counts().reset_index()
tag_counts.columns = ["tag", "video_count"]

tag_counts.head()
# Out:
#         tag  video_count
# 0    [none]        37698
# 1   "funny"        14969
# 2  "comedy"        11967
# 3    "2018"        11047
# 4    "news"         6004

# %% [markdown]
# # 9. Find the tags with the largest number of videos

# %%
# Task 9: Tags with the most videos
top_tags = tag_counts.sort_values("video_count", ascending=False)

top_tags.head(10)
# Out:
#             tag  video_count
# 0        [none]        37698
# 1       "funny"        14969
# 2      "comedy"        11967
# 3        "2018"        11047
# 4        "news"         6004
# 5       "music"         5599
# 6        "2017"         5510
# 7       "video"         5419
# 8       "humor"         5037
# 9  "television"         4164

# %% [markdown]
# # 10. For each (tag, country) pair, compute average ratio likes/dislikes

# %%
# Task 10: For each (tag, country) pair, compute average like_ratio

tag_country_ratio = df_tags.groupby(["tag", "country"])["like_ratio"].mean().reset_index()

tag_country_ratio.head()
# Out:
#                 tag country like_ratio
# 0      #Freeticket"      IN   2.665679
# 1             #GST       IN   2.416896
# 2        #Jaisimha       IN   2.665679
# 3   #JanaSenaParty       IN  17.621907
# 4       #MahaaNews"      IN   8.511947

# %% [markdown]
# # 11. For each (trending_date, country) pair, the video with the largest number of views

# %%
# top_videos = df.loc[
#     df.groupby(["trending_date", "country"])["views"].idxmax()
# ]
# top_videos.head(100)
# Task: For each (trending_date, country) pair, show the video with the highest views
# Columns required: trending_date, country, channel_title, tags, views, likes

top_videos = df.loc[
    df.groupby(["trending_date", "country"])["views"].idxmax(),
    ["trending_date", "country", "channel_title", "tags", "views", "likes"]
].reset_index(drop=True)

top_videos
# Out:
#      trending_date country         channel_title  \
# 0         17.01.12      CA  Marvel Entertainment
# 1         17.01.12      DE  Marvel Entertainment
# 2         17.01.12      FR  Marvel Entertainment
# 3         17.01.12      GB         LuisFonsiVEVO
# 4         17.01.12      IN  Marvel Entertainment
# ...            ...     ...                   ...
# 1962      18.31.05      JP           Maroon5VEVO
# 1963      18.31.05      KR          1theK (원더케이)
# 1964      18.31.05      MX               Cardi B
# 1965      18.31.05      RU           BadComedian
# 1966      18.31.05      US   ChildishGambinoVEVO
#
#                                                    tags      views    likes
# 0     marvel|"comics"|"comic books"|"nerdy"|"geeky"|...   56367282  2157741
# 1     marvel|"comics"|"comic books"|"nerdy"|"geeky"|...   56367282  2157737
# 2     marvel"|"comics"|"comic books"|"nerdy"|"geeky"...    7281189   180808
# 3     Luis|"Fonsi"|"Demi"|"Lovato"|"Échame"|"La"|"Cu...  143408235  2686169
# 4     marvel|"comics"|"comic books"|"nerdy"|"geeky"|...   56367282  2157733
# ...                                                 ...        ...      ...
# 1962  Maroon|"Girls"|"Like"|"You"|"Interscope"|"Reco...    3057987   406732
# 1963  Kpop|"1theK"|"원더케이"|"loen"|"로엔"|"뮤비"|"티져"|"MV"...    4150448   186262
# 1964  Cardi B|"I Like It"|"Invasion of Privacy"|"Bad...   20723565  1018817
# 1965  BadComedian|"Евген"|"Bad"|"Comedian"|"Фильмы"|...    3125598   334685
# 1966  Childish Gambino|"Rap"|"This Is America"|"mcDJ...  217750076  4934188
#
# [1967 rows x 6 columns]

# %% [markdown]
# # 12. Divide trending_date into three columns: year, month, day

# %%
# # Convert to datetime if not already
# df["trending_date"] = pd.to_datetime(df["trending_date"])

# # Extract date components
# df["trending_year"] = df["trending_date"].dt.year
# df["trending_month"] = df["trending_date"].dt.month
# df["trending_day"] = df["trending_date"].dt.day

# trending_date format is YY.DD.MM → we must parse manually
df["trending_date"] = pd.to_datetime(df["trending_date"], format="%y.%d.%m")

# Split into year, month, day
df["trending_year"] = df["trending_date"].dt.year
df["trending_month"] = df["trending_date"].dt.month
df["trending_day"] = df["trending_date"].dt.day

df[["trending_date", "trending_year", "trending_month", "trending_day"]].head()
# Out:
#   trending_date  trending_year  trending_month  trending_day
# 0    2017-11-14           2017              11            14
# 1    2017-11-14           2017              11            14
# 2    2017-11-14           2017              11            14
# 3    2017-11-14           2017              11            14
# 4    2017-11-14           2017              11            14

# %% [markdown]
# ## 13. For each (month, country) pair, the video with the largest number of views

# %%
# Task 13: For each (month, country) pair, the video with the highest number of views

top_month_country = df.loc[
    df.groupby(["trending_month", "country"])["views"].idxmax(),
    ["trending_month", "country", "channel_title", "title", "tags", "views", "likes"]
].reset_index(drop=True)

top_month_country
# Out:
#     trending_month country      channel_title  \
# 0                1      CA         Bruno Mars
# 1                1      DE         Bruno Mars
# 2                1      FR         Bruno Mars
# 3                1      GB         Bruno Mars
# 4                1      IN    TaylorSwiftVEVO
# ..             ...     ...                ...
# 72              12      IN  YouTube Spotlight
# 73              12      KR  YouTube Spotlight
# 74              12      MX  YouTube Spotlight
# 75              12      RU  YouTube Spotlight
# 76              12      US  YouTube Spotlight
#
#                                                 title  \
# 0   Bruno Mars - Finesse (Remix) [Feat. Cardi B] [...
# 1   Bruno Mars - Finesse (Remix) [Feat. Cardi B] [...
# 2   Bruno Mars - Finesse (Remix) [Feat. Cardi B] [...
# 3   Bruno Mars - Finesse (Remix) [Feat. Cardi B] [...
# 4      Taylor Swift - End Game ft. Ed Sheeran, Future
# ..                                                ...
# 72  YouTube Rewind: The Shape of 2017 | #YouTubeRe...
# 73  YouTube Rewind: The Shape of 2017 | #YouTubeRe...
# 74  YouTube Rewind: The Shape of 2017 | #YouTubeRe...
# 75  YouTube Rewind: The Shape of 2017 | #YouTubeRe...
# 76  YouTube Rewind: The Shape of 2017 | #YouTubeRe...
#
#                                                  tags      views    likes
# 0   Bruno Mars|"Finesse"|"Cardi B"|"Finesse Remix"...   43067983  1717177
# 1   Bruno Mars|"Finesse"|"Cardi B"|"Finesse Remix"...   37728802  1629946
# 2   Bruno Mars"|"Finesse"|"Cardi B"|"Finesse Remix...   37728802  1629948
# 3   Bruno Mars|"Finesse"|"Cardi B"|"Finesse Remix"...   90598955  2248693
# 4   Taylor|"Swift"|"End"|"Game"|"Big"|"Machine"|"Pop"   42019590  1804377
# ..                                                ...        ...      ...
# 72  Rewind|"Rewind 2017"|"youtube rewind 2017"|"#Y...  125432237  2912710
# 73  Rewind|"Rewind 2017"|"youtube rewind 2017"|"#Y...  113876217  2811223
# 74  Rewind|"Rewind 2017"|"youtube rewind 2017"|"#Y...  100912384  2656698
# 75  Rewind|"Rewind 2017"|"youtube rewind 2017"|"#Y...   52611730  1891836
# 76  Rewind|"Rewind 2017"|"youtube rewind 2017"|"#Y...  149376127  3093544
#
# [77 rows x 7 columns]

# %% [markdown]
# ## 14. Read all json files with the video categories

# %%
import json
from pathlib import Path

# Folder where JSON files are stored
json_path = Path("../data")

# Get all JSON files
json_files = sorted(json_path.glob("*.json"))

categories = {}

for jf in json_files:
    country = jf.stem[:2]   # Extract country code from filename (e.g., US_category.json → US)
    
    with open(jf, "r", encoding="utf-8") as f:
        data = json.load(f)
    
    categories[country] = pd.json_normalize(data["items"])

categories
# Out:
# {'CA':                      kind                                               etag  \
#  0   youtube#videoCategory  "ld9biNPKjAjgjV7EZ4EKeEGrhao/Xy1mB4_yLrHy_BmKm...
#  1   youtube#videoCategory  "ld9biNPKjAjgjV7EZ4EKeEGrhao/UZ1oLIIz2dxIhO45Z...
#  2   youtube#videoCategory  "ld9biNPKjAjgjV7EZ4EKeEGrhao/nqRIq97-xe5XRZTxb...
#  3   youtube#videoCategory  "ld9biNPKjAjgjV7EZ4EKeEGrhao/HwXKamM1Q20q9BN-o...
#  4   youtube#videoCategory  "ld9biNPKjAjgjV7EZ4EKeEGrhao/9GQMSRjrZdHeb1OEM...
#  5   youtube#videoCategory  "ld9biNPKjAjgjV7EZ4EKeEGrhao/FJwVpGCVZ1yiJrqZb...
#  6   youtube#videoCategory  "ld9biNPKjAjgjV7EZ4EKeEGrhao/M-3iD9dwK7YJCafRf...
#  7   youtube#videoCategory  "ld9biNPKjAjgjV7EZ4EKeEGrhao/WmA0qYEfjWsAoyJFS...
#  8   youtube#videoCategory  "ld9biNPKjAjgjV7EZ4EKeEGrhao/EapFaGYG7K0StIXVf...
#  9   youtube#videoCategory  "ld9biNPKjAjgjV7EZ4EKeEGrhao/xId8RX7vRN8rqkbYZ...
#  10  youtube#videoCategory  "ld9biNPKjAjgjV7EZ4EKeEGrhao/G9LHzQmx44rX2S5ya...
#  11  youtube#videoCategory  "ld9biNPKjAjgjV7EZ4EKeEGrhao/UVB9oxX2Bvqa_w_y3...
#  12  youtube#videoCategory  "ld9biNPKjAjgjV7EZ4EKeEGrhao/QiLK0ZIrFoORdk_g2...
#  13  youtube#videoCategory  "ld9biNPKjAjgjV7EZ4EKeEGrhao/r6Ck6Z0_L0rG37VJQ...
#  14  youtube#videoCategory  "ld9biNPKjAjgjV7EZ4EKeEGrhao/EoYkczo9I3RCf96Rv...
#  15  youtube#videoCategory  "ld9biNPKjAjgjV7EZ4EKeEGrhao/w5HjcTD82G_XA3xBc...
#  16  youtube#videoCategory  "ld9biNPKjAjgjV7EZ4EKeEGrhao/lL7uWDr_071CHxifj...
#  17  youtube#videoCategory  "ld9biNPKjAjgjV7EZ4EKeEGrhao/WnuVfjO-PyFLO7NTR...
#  18  youtube#videoCategory  "ld9biNPKjAjgjV7EZ4EKeEGrhao/ctpH2hGA_UZ3volJT...
#  19  youtube#videoCategory  "ld9biNPKjAjgjV7EZ4EKeEGrhao/L0kR3-g1BAo5UD1PL...
#  20  youtube#videoCategory  "ld9biNPKjAjgjV7EZ4EKeEGrhao/pUZOAC_s9sfiwar63...
#  21  youtube#videoCategory  "ld9biNPKjAjgjV7EZ4EKeEGrhao/Xb5JLhtyNRN3AQq02...
#  22  youtube#videoCategory  "ld9biNPKjAjgjV7EZ4EKeEGrhao/u8WXzF4HIhtEi805_...
#  23  youtube#videoCategory  "ld9biNPKjAjgjV7EZ4EKeEGrhao/D04PP4Gr7wc4IV_O9...
#  24  youtube#videoCategory  "ld9biNPKjAjgjV7EZ4EKeEGrhao/i5-_AceGXQCEEMWU0...
#  25  youtube#videoCategory  "ld9biNPKjAjgjV7EZ4EKeEGrhao/rtlxd0zOixA9QHdIZ...
#  26  youtube#videoCategory  "ld9biNPKjAjgjV7EZ4EKeEGrhao/N1TrDFLRppxZgBowC...
#  27  youtube#videoCategory  "ld9biNPKjAjgjV7EZ4EKeEGrhao/7UMGi6zRySqXopr_r...
#  28  youtube#videoCategory  "ld9biNPKjAjgjV7EZ4EKeEGrhao/RScXhi324h8usyIet...
#  29  youtube#videoCategory  "ld9biNPKjAjgjV7EZ4EKeEGrhao/0n9MJVCDLpA8q7aiG...
#  30  youtube#videoCategory  "ld9biNPKjAjgjV7EZ4EKeEGrhao/x5NxSf5fz8hn4loSN...
#
#      id         snippet.channelId         snippet.title  snippet.assignable
#  0    1  UCBR8-60-B28hp2BmDPdntcQ      Film & Animation                True
#  1    2  UCBR8-60-B28hp2BmDPdntcQ      Autos & Vehicles                True
#  2   10  UCBR8-60-B28hp2BmDPdntcQ                 Music                True
#  3   15  UCBR8-60-B28hp2BmDPdntcQ        Pets & Animals                True
#  4   17  UCBR8-60-B28hp2BmDPdntcQ                Sports                True
#  5   18  UCBR8-60-B28hp2BmDPdntcQ          Short Movies               False
#  6   19  UCBR8-60-B28hp2BmDPdntcQ       Travel & Events                True
#  7   20  UCBR8-60-B28hp2BmDPdntcQ                Gaming                True
#  8   21  UCBR8-60-B28hp2BmDPdntcQ         Videoblogging               False
#  9   22  UCBR8-60-B28hp2BmDPdntcQ        People & Blogs                True
#  10  23  UCBR8-60-B28hp2BmDPdntcQ                Comedy                True
#  11  24  UCBR8-60-B28hp2BmDPdntcQ         Entertainment                True
#  12  25  UCBR8-60-B28hp2BmDPdntcQ       News & Politics                True
#  13  26  UCBR8-60-B28hp2BmDPdntcQ         Howto & Style                True
#  14  27  UCBR8-60-B28hp2BmDPdntcQ             Education                True
#  15  28  UCBR8-60-B28hp2BmDPdntcQ  Science & Technology                True
#  16  30  UCBR8-60-B28hp2BmDPdntcQ                Movies               False
#  17  31  UCBR8-60-B28hp2BmDPdntcQ       Anime/Animation               False
#  18  32  UCBR8-60-B28hp2BmDPdntcQ      Action/Adventure               False
#  19  33  UCBR8-60-B28hp2BmDPdntcQ              Classics               False
#  20  34  UCBR8-60-B28hp2BmDPdntcQ                Comedy               False
#  21  35  UCBR8-60-B28hp2BmDPdntcQ           Documentary               False
#  22  36  UCBR8-60-B28hp2BmDPdntcQ                 Drama               False
#  23  37  UCBR8-60-B28hp2BmDPdntcQ                Family               False
#  24  38  UCBR8-60-B28hp2BmDPdntcQ               Foreign               False
#  25  39  UCBR8-60-B28hp2BmDPdntcQ                Horror               False
#  26  40  UCBR8-60-B28hp2BmDPdntcQ        Sci-Fi/Fantasy               False
#  27  41  UCBR8-60-B28hp2BmDPdntcQ              Thriller               False
#  28  42  UCBR8-60-B28hp2BmDPdntcQ                Shorts               False
#  29  43  UCBR8-60-B28hp2BmDPdntcQ                 Shows               False
#  30  44  UCBR8-60-B28hp2BmDPdntcQ              Trailers               False  ,
#  'DE':                      kind                                               etag  \
#  0   youtube#videoCategory  "ld9biNPKjAjgjV7EZ4EKeEGrhao/Xy1mB4_yLrHy_BmKm...
#  1   youtube#videoCategory  "ld9biNPKjAjgjV7EZ4EKeEGrhao/UZ1oLIIz2dxIhO45Z...
#  2   youtube#videoCategory  "ld9biNPKjAjgjV7EZ4EKeEGrhao/nqRIq97-xe5XRZTxb...
#  3   youtube#videoCategory  "ld9biNPKjAjgjV7EZ4EKeEGrhao/HwXKamM1Q20q9BN-o...
#  4   youtube#videoCategory  "ld9biNPKjAjgjV7EZ4EKeEGrhao/9GQMSRjrZdHeb1OEM...
#  5   youtube#videoCategory  "ld9biNPKjAjgjV7EZ4EKeEGrhao/FJwVpGCVZ1yiJrqZb...
#  6   youtube#videoCategory  "ld9biNPKjAjgjV7EZ4EKeEGrhao/M-3iD9dwK7YJCafRf...
#  7   youtube#videoCategory  "ld9biNPKjAjgjV7EZ4EKeEGrhao/WmA0qYEfjWsAoyJFS...
#  8   youtube#videoCategory  "ld9biNPKjAjgjV7EZ4EKeEGrhao/EapFaGYG7K0StIXVf...
#  9   youtube#videoCategory  "ld9biNPKjAjgjV7EZ4EKeEGrhao/xId8RX7vRN8rqkbYZ...
#  10  youtube#videoCategory  "ld9biNPKjAjgjV7EZ4EKeEGrhao/G9LHzQmx44rX2S5ya...
#  11  youtube#videoCategory  "ld9biNPKjAjgjV7EZ4EKeEGrhao/UVB9oxX2Bvqa_w_y3...
#  12  youtube#videoCategory  "ld9biNPKjAjgjV7EZ4EKeEGrhao/QiLK0ZIrFoORdk_g2...
#  13  youtube#videoCategory  "ld9biNPKjAjgjV7EZ4EKeEGrhao/r6Ck6Z0_L0rG37VJQ...
#  14  youtube#videoCategory  "ld9biNPKjAjgjV7EZ4EKeEGrhao/EoYkczo9I3RCf96Rv...
#  15  youtube#videoCategory  "ld9biNPKjAjgjV7EZ4EKeEGrhao/w5HjcTD82G_XA3xBc...
#  16  youtube#videoCategory  "ld9biNPKjAjgjV7EZ4EKeEGrhao/lL7uWDr_071CHxifj...
#  17  youtube#videoCategory  "ld9biNPKjAjgjV7EZ4EKeEGrhao/WnuVfjO-PyFLO7NTR...
#  18  youtube#videoCategory  "ld9biNPKjAjgjV7EZ4EKeEGrhao/ctpH2hGA_UZ3volJT...
#  19  youtube#videoCategory  "ld9biNPKjAjgjV7EZ4EKeEGrhao/L0kR3-g1BAo5UD1PL...
#  20  youtube#videoCategory  "ld9biNPKjAjgjV7EZ4EKeEGrhao/pUZOAC_s9sfiwar63...
#  21  youtube#videoCategory  "ld9biNPKjAjgjV7EZ4EKeEGrhao/Xb5JLhtyNRN3AQq02...
#  22  youtube#videoCategory  "ld9biNPKjAjgjV7EZ4EKeEGrhao/u8WXzF4HIhtEi805_...
#  23  youtube#videoCategory  "ld9biNPKjAjgjV7EZ4EKeEGrhao/D04PP4Gr7wc4IV_O9...
#  24  youtube#videoCategory  "ld9biNPKjAjgjV7EZ4EKeEGrhao/i5-_AceGXQCEEMWU0...
#  25  youtube#videoCategory  "ld9biNPKjAjgjV7EZ4EKeEGrhao/rtlxd0zOixA9QHdIZ...
#  26  youtube#videoCategory  "ld9biNPKjAjgjV7EZ4EKeEGrhao/N1TrDFLRppxZgBowC...
#  27  youtube#videoCategory  "ld9biNPKjAjgjV7EZ4EKeEGrhao/7UMGi6zRySqXopr_r...
#  28  youtube#videoCategory  "ld9biNPKjAjgjV7EZ4EKeEGrhao/RScXhi324h8usyIet...
#  29  youtube#videoCategory  "ld9biNPKjAjgjV7EZ4EKeEGrhao/0n9MJVCDLpA8q7aiG...
#  30  youtube#videoCategory  "ld9biNPKjAjgjV7EZ4EKeEGrhao/x5NxSf5fz8hn4loSN...
#
#      id         snippet.channelId         snippet.title  snippet.assignable
#  0    1  UCBR8-60-B28hp2BmDPdntcQ      Film & Animation                True
#  1    2  UCBR8-60-B28hp2BmDPdntcQ      Autos & Vehicles                True
#  2   10  UCBR8-60-B28hp2BmDPdntcQ                 Music                True
#  3   15  UCBR8-60-B28hp2BmDPdntcQ        Pets & Animals                True
#  4   17  UCBR8-60-B28hp2BmDPdntcQ                Sports                True
#  5   18  UCBR8-60-B28hp2BmDPdntcQ          Short Movies               False
#  6   19  UCBR8-60-B28hp2BmDPdntcQ       Travel & Events                True
#  7   20  UCBR8-60-B28hp2BmDPdntcQ                Gaming                True
#  8   21  UCBR8-60-B28hp2BmDPdntcQ         Videoblogging               False
#  9   22  UCBR8-60-B28hp2BmDPdntcQ        People & Blogs                True
#  10  23  UCBR8-60-B28hp2BmDPdntcQ                Comedy                True
#  11  24  UCBR8-60-B28hp2BmDPdntcQ         Entertainment                True
#  12  25  UCBR8-60-B28hp2BmDPdntcQ       News & Politics                True
#  13  26  UCBR8-60-B28hp2BmDPdntcQ         Howto & Style                True
#  14  27  UCBR8-60-B28hp2BmDPdntcQ             Education                True
#  15  28  UCBR8-60-B28hp2BmDPdntcQ  Science & Technology                True
#  16  30  UCBR8-60-B28hp2BmDPdntcQ                Movies               False
#  17  31  UCBR8-60-B28hp2BmDPdntcQ       Anime/Animation               False
#  18  32  UCBR8-60-B28hp2BmDPdntcQ      Action/Adventure               False
#  19  33  UCBR8-60-B28hp2BmDPdntcQ              Classics               False
#  20  34  UCBR8-60-B28hp2BmDPdntcQ                Comedy               False
#  21  35  UCBR8-60-B28hp2BmDPdntcQ           Documentary               False
#  22  36  UCBR8-60-B28hp2BmDPdntcQ                 Drama               False
#  23  37  UCBR8-60-B28hp2BmDPdntcQ                Family               False
#  24  38  UCBR8-60-B28hp2BmDPdntcQ               Foreign               False
#  25  39  UCBR8-60-B28hp2BmDPdntcQ                Horror               False
#  26  40  UCBR8-60-B28hp2BmDPdntcQ        Sci-Fi/Fantasy               False
#  27  41  UCBR8-60-B28hp2BmDPdntcQ              Thriller               False
#  28  42  UCBR8-60-B28hp2BmDPdntcQ                Shorts               False
#  29  43  UCBR8-60-B28hp2BmDPdntcQ                 Shows               False
#  30  44  UCBR8-60-B28hp2BmDPdntcQ              Trailers               False  ,
#  'FR':                      kind                                               etag  \
#  0   youtube#videoCategory  "ld9biNPKjAjgjV7EZ4EKeEGrhao/Xy1mB4_yLrHy_BmKm...
#  1   youtube#videoCategory  "ld9biNPKjAjgjV7EZ4EKeEGrhao/UZ1oLIIz2dxIhO45Z...
#  2   youtube#videoCategory  "ld9biNPKjAjgjV7EZ4EKeEGrhao/nqRIq97-xe5XRZTxb...
#  3   youtube#videoCategory  "ld9biNPKjAjgjV7EZ4EKeEGrhao/HwXKamM1Q20q9BN-o...
#  4   youtube#videoCategory  "ld9biNPKjAjgjV7EZ4EKeEGrhao/9GQMSRjrZdHeb1OEM...
#  5   youtube#videoCategory  "ld9biNPKjAjgjV7EZ4EKeEGrhao/FJwVpGCVZ1yiJrqZb...
#  6   youtube#videoCategory  "ld9biNPKjAjgjV7EZ4EKeEGrhao/M-3iD9dwK7YJCafRf...
#  7   youtube#videoCategory  "ld9biNPKjAjgjV7EZ4EKeEGrhao/WmA0qYEfjWsAoyJFS...
#  8   youtube#videoCategory  "ld9biNPKjAjgjV7EZ4EKeEGrhao/EapFaGYG7K0StIXVf...
#  9   youtube#videoCategory  "ld9biNPKjAjgjV7EZ4EKeEGrhao/xId8RX7vRN8rqkbYZ...
#  10  youtube#videoCategory  "ld9biNPKjAjgjV7EZ4EKeEGrhao/G9LHzQmx44rX2S5ya...
#  11  youtube#videoCategory  "ld9biNPKjAjgjV7EZ4EKeEGrhao/UVB9oxX2Bvqa_w_y3...
#  12  youtube#videoCategory  "ld9biNPKjAjgjV7EZ4EKeEGrhao/QiLK0ZIrFoORdk_g2...
#  13  youtube#videoCategory  "ld9biNPKjAjgjV7EZ4EKeEGrhao/r6Ck6Z0_L0rG37VJQ...
#  14  youtube#videoCategory  "ld9biNPKjAjgjV7EZ4EKeEGrhao/EoYkczo9I3RCf96Rv...
#  15  youtube#videoCategory  "ld9biNPKjAjgjV7EZ4EKeEGrhao/w5HjcTD82G_XA3xBc...
#  16  youtube#videoCategory  "ld9biNPKjAjgjV7EZ4EKeEGrhao/lL7uWDr_071CHxifj...
#  17  youtube#videoCategory  "ld9biNPKjAjgjV7EZ4EKeEGrhao/WnuVfjO-PyFLO7NTR...
#  18  youtube#videoCategory  "ld9biNPKjAjgjV7EZ4EKeEGrhao/ctpH2hGA_UZ3volJT...
#  19  youtube#videoCategory  "ld9biNPKjAjgjV7EZ4EKeEGrhao/L0kR3-g1BAo5UD1PL...
#  20  youtube#videoCategory  "ld9biNPKjAjgjV7EZ4EKeEGrhao/pUZOAC_s9sfiwar63...
#  21  youtube#videoCategory  "ld9biNPKjAjgjV7EZ4EKeEGrhao/Xb5JLhtyNRN3AQq02...
#  22  youtube#videoCategory  "ld9biNPKjAjgjV7EZ4EKeEGrhao/u8WXzF4HIhtEi805_...
#  23  youtube#videoCategory  "ld9biNPKjAjgjV7EZ4EKeEGrhao/D04PP4Gr7wc4IV_O9...
#  24  youtube#videoCategory  "ld9biNPKjAjgjV7EZ4EKeEGrhao/i5-_AceGXQCEEMWU0...
#  25  youtube#videoCategory  "ld9biNPKjAjgjV7EZ4EKeEGrhao/rtlxd0zOixA9QHdIZ...
#  26  youtube#videoCategory  "ld9biNPKjAjgjV7EZ4EKeEGrhao/N1TrDFLRppxZgBowC...
#  27  youtube#videoCategory  "ld9biNPKjAjgjV7EZ4EKeEGrhao/7UMGi6zRySqXopr_r...
#  28  youtube#videoCategory  "ld9biNPKjAjgjV7EZ4EKeEGrhao/RScXhi324h8usyIet...
#  29  youtube#videoCategory  "ld9biNPKjAjgjV7EZ4EKeEGrhao/0n9MJVCDLpA8q7aiG...
#  30  youtube#videoCategory  "ld9biNPKjAjgjV7EZ4EKeEGrhao/x5NxSf5fz8hn4loSN...
#
#      id         snippet.channelId         snippet.title  snippet.assignable
#  0    1  UCBR8-60-B28hp2BmDPdntcQ      Film & Animation                True
#  1    2  UCBR8-60-B28hp2BmDPdntcQ      Autos & Vehicles                True
#  2   10  UCBR8-60-B28hp2BmDPdntcQ                 Music                True
#  3   15  UCBR8-60-B28hp2BmDPdntcQ        Pets & Animals                True
#  4   17  UCBR8-60-B28hp2BmDPdntcQ                Sports                True
#  5   18  UCBR8-60-B28hp2BmDPdntcQ          Short Movies               False
#  6   19  UCBR8-60-B28hp2BmDPdntcQ       Travel & Events                True
#  7   20  UCBR8-60-B28hp2BmDPdntcQ                Gaming                True
#  8   21  UCBR8-60-B28hp2BmDPdntcQ         Videoblogging               False
#  9   22  UCBR8-60-B28hp2BmDPdntcQ        People & Blogs                True
#  10  23  UCBR8-60-B28hp2BmDPdntcQ                Comedy                True
#  11  24  UCBR8-60-B28hp2BmDPdntcQ         Entertainment                True
#  12  25  UCBR8-60-B28hp2BmDPdntcQ       News & Politics                True
#  13  26  UCBR8-60-B28hp2BmDPdntcQ         Howto & Style                True
#  14  27  UCBR8-60-B28hp2BmDPdntcQ             Education                True
#  15  28  UCBR8-60-B28hp2BmDPdntcQ  Science & Technology                True
#  16  30  UCBR8-60-B28hp2BmDPdntcQ                Movies               False
#  17  31  UCBR8-60-B28hp2BmDPdntcQ       Anime/Animation               False
#  18  32  UCBR8-60-B28hp2BmDPdntcQ      Action/Adventure               False
#  19  33  UCBR8-60-B28hp2BmDPdntcQ              Classics               False
#  20  34  UCBR8-60-B28hp2BmDPdntcQ                Comedy               False
#  21  35  UCBR8-60-B28hp2BmDPdntcQ           Documentary               False
#  22  36  UCBR8-60-B28hp2BmDPdntcQ                 Drama               False
#  23  37  UCBR8-60-B28hp2BmDPdntcQ                Family               False
#  24  38  UCBR8-60-B28hp2BmDPdntcQ               Foreign               False
#  25  39  UCBR8-60-B28hp2BmDPdntcQ                Horror               False
#  26  40  UCBR8-60-B28hp2BmDPdntcQ        Sci-Fi/Fantasy               False
#  27  41  UCBR8-60-B28hp2BmDPdntcQ              Thriller               False
#  28  42  UCBR8-60-B28hp2BmDPdntcQ                Shorts               False
#  29  43  UCBR8-60-B28hp2BmDPdntcQ                 Shows               False
#  30  44  UCBR8-60-B28hp2BmDPdntcQ              Trailers               False  ,
#  'GB':                      kind                                               etag  \
#  0   youtube#videoCategory  "m2yskBQFythfE4irbTIeOgYYfBU/Xy1mB4_yLrHy_BmKm...
#  1   youtube#videoCategory  "m2yskBQFythfE4irbTIeOgYYfBU/UZ1oLIIz2dxIhO45Z...
#  2   youtube#videoCategory  "m2yskBQFythfE4irbTIeOgYYfBU/nqRIq97-xe5XRZTxb...
#  3   youtube#videoCategory  "m2yskBQFythfE4irbTIeOgYYfBU/HwXKamM1Q20q9BN-o...
#  4   youtube#videoCategory  "m2yskBQFythfE4irbTIeOgYYfBU/9GQMSRjrZdHeb1OEM...
#  5   youtube#videoCategory  "m2yskBQFythfE4irbTIeOgYYfBU/FJwVpGCVZ1yiJrqZb...
#  6   youtube#videoCategory  "m2yskBQFythfE4irbTIeOgYYfBU/M-3iD9dwK7YJCafRf...
#  7   youtube#videoCategory  "m2yskBQFythfE4irbTIeOgYYfBU/WmA0qYEfjWsAoyJFS...
#  8   youtube#videoCategory  "m2yskBQFythfE4irbTIeOgYYfBU/EapFaGYG7K0StIXVf...
#  9   youtube#videoCategory  "m2yskBQFythfE4irbTIeOgYYfBU/xId8RX7vRN8rqkbYZ...
#  10  youtube#videoCategory  "m2yskBQFythfE4irbTIeOgYYfBU/G9LHzQmx44rX2S5ya...
#  11  youtube#videoCategory  "m2yskBQFythfE4irbTIeOgYYfBU/UVB9oxX2Bvqa_w_y3...
#  12  youtube#videoCategory  "m2yskBQFythfE4irbTIeOgYYfBU/QiLK0ZIrFoORdk_g2...
#  13  youtube#videoCategory  "m2yskBQFythfE4irbTIeOgYYfBU/r6Ck6Z0_L0rG37VJQ...
#  14  youtube#videoCategory  "m2yskBQFythfE4irbTIeOgYYfBU/EoYkczo9I3RCf96Rv...
#  15  youtube#videoCategory  "m2yskBQFythfE4irbTIeOgYYfBU/w5HjcTD82G_XA3xBc...
#  16  youtube#videoCategory  "m2yskBQFythfE4irbTIeOgYYfBU/lL7uWDr_071CHxifj...
#  17  youtube#videoCategory  "m2yskBQFythfE4irbTIeOgYYfBU/WnuVfjO-PyFLO7NTR...
#  18  youtube#videoCategory  "m2yskBQFythfE4irbTIeOgYYfBU/ctpH2hGA_UZ3volJT...
#  19  youtube#videoCategory  "m2yskBQFythfE4irbTIeOgYYfBU/L0kR3-g1BAo5UD1PL...
#  20  youtube#videoCategory  "m2yskBQFythfE4irbTIeOgYYfBU/pUZOAC_s9sfiwar63...
#  21  youtube#videoCategory  "m2yskBQFythfE4irbTIeOgYYfBU/Xb5JLhtyNRN3AQq02...
#  22  youtube#videoCategory  "m2yskBQFythfE4irbTIeOgYYfBU/u8WXzF4HIhtEi805_...
#  23  youtube#videoCategory  "m2yskBQFythfE4irbTIeOgYYfBU/D04PP4Gr7wc4IV_O9...
#  24  youtube#videoCategory  "m2yskBQFythfE4irbTIeOgYYfBU/i5-_AceGXQCEEMWU0...
#  25  youtube#videoCategory  "m2yskBQFythfE4irbTIeOgYYfBU/rtlxd0zOixA9QHdIZ...
#  26  youtube#videoCategory  "m2yskBQFythfE4irbTIeOgYYfBU/N1TrDFLRppxZgBowC...
#  27  youtube#videoCategory  "m2yskBQFythfE4irbTIeOgYYfBU/7UMGi6zRySqXopr_r...
#  28  youtube#videoCategory  "m2yskBQFythfE4irbTIeOgYYfBU/RScXhi324h8usyIet...
#  29  youtube#videoCategory  "m2yskBQFythfE4irbTIeOgYYfBU/0n9MJVCDLpA8q7aiG...
#  30  youtube#videoCategory  "m2yskBQFythfE4irbTIeOgYYfBU/x5NxSf5fz8hn4loSN...
#
#      id         snippet.channelId         snippet.title  snippet.assignable
#  0    1  UCBR8-60-B28hp2BmDPdntcQ      Film & Animation                True
#  1    2  UCBR8-60-B28hp2BmDPdntcQ      Autos & Vehicles                True
#  2   10  UCBR8-60-B28hp2BmDPdntcQ                 Music                True
#  3   15  UCBR8-60-B28hp2BmDPdntcQ        Pets & Animals                True
#  4   17  UCBR8-60-B28hp2BmDPdntcQ                Sports                True
#  5   18  UCBR8-60-B28hp2BmDPdntcQ          Short Movies               False
#  6   19  UCBR8-60-B28hp2BmDPdntcQ       Travel & Events                True
#  7   20  UCBR8-60-B28hp2BmDPdntcQ                Gaming                True
#  8   21  UCBR8-60-B28hp2BmDPdntcQ         Videoblogging               False
#  9   22  UCBR8-60-B28hp2BmDPdntcQ        People & Blogs                True
#  10  23  UCBR8-60-B28hp2BmDPdntcQ                Comedy                True
#  11  24  UCBR8-60-B28hp2BmDPdntcQ         Entertainment                True
#  12  25  UCBR8-60-B28hp2BmDPdntcQ       News & Politics                True
#  13  26  UCBR8-60-B28hp2BmDPdntcQ         Howto & Style                True
#  14  27  UCBR8-60-B28hp2BmDPdntcQ             Education                True
#  15  28  UCBR8-60-B28hp2BmDPdntcQ  Science & Technology                True
#  16  30  UCBR8-60-B28hp2BmDPdntcQ                Movies               False
#  17  31  UCBR8-60-B28hp2BmDPdntcQ       Anime/Animation               False
#  18  32  UCBR8-60-B28hp2BmDPdntcQ      Action/Adventure               False
#  19  33  UCBR8-60-B28hp2BmDPdntcQ              Classics               False
#  20  34  UCBR8-60-B28hp2BmDPdntcQ                Comedy               False
#  21  35  UCBR8-60-B28hp2BmDPdntcQ           Documentary               False
#  22  36  UCBR8-60-B28hp2BmDPdntcQ                 Drama               False
#  23  37  UCBR8-60-B28hp2BmDPdntcQ                Family               False
#  24  38  UCBR8-60-B28hp2BmDPdntcQ               Foreign               False
#  25  39  UCBR8-60-B28hp2BmDPdntcQ                Horror               False
#  26  40  UCBR8-60-B28hp2BmDPdntcQ        Sci-Fi/Fantasy               False
#  27  41  UCBR8-60-B28hp2BmDPdntcQ              Thriller               False
#  28  42  UCBR8-60-B28hp2BmDPdntcQ                Shorts               False
#  29  43  UCBR8-60-B28hp2BmDPdntcQ                 Shows               False
#  30  44  UCBR8-60-B28hp2BmDPdntcQ              Trailers               False  ,
#  'IN':                      kind                                               etag  \
#  0   youtube#videoCategory  "XI7nbFXulYBIpL0ayR_gDh3eu1k/Xy1mB4_yLrHy_BmKm...
#  1   youtube#videoCategory  "XI7nbFXulYBIpL0ayR_gDh3eu1k/UZ1oLIIz2dxIhO45Z...
#  2   youtube#videoCategory  "XI7nbFXulYBIpL0ayR_gDh3eu1k/nqRIq97-xe5XRZTxb...
#  3   youtube#videoCategory  "XI7nbFXulYBIpL0ayR_gDh3eu1k/HwXKamM1Q20q9BN-o...
#  4   youtube#videoCategory  "XI7nbFXulYBIpL0ayR_gDh3eu1k/9GQMSRjrZdHeb1OEM...
#  5   youtube#videoCategory  "XI7nbFXulYBIpL0ayR_gDh3eu1k/FJwVpGCVZ1yiJrqZb...
#  6   youtube#videoCategory  "XI7nbFXulYBIpL0ayR_gDh3eu1k/M-3iD9dwK7YJCafRf...
#  7   youtube#videoCategory  "XI7nbFXulYBIpL0ayR_gDh3eu1k/WmA0qYEfjWsAoyJFS...
#  8   youtube#videoCategory  "XI7nbFXulYBIpL0ayR_gDh3eu1k/EapFaGYG7K0StIXVf...
#  9   youtube#videoCategory  "XI7nbFXulYBIpL0ayR_gDh3eu1k/xId8RX7vRN8rqkbYZ...
#  10  youtube#videoCategory  "XI7nbFXulYBIpL0ayR_gDh3eu1k/G9LHzQmx44rX2S5ya...
#  11  youtube#videoCategory  "XI7nbFXulYBIpL0ayR_gDh3eu1k/UVB9oxX2Bvqa_w_y3...
#  12  youtube#videoCategory  "XI7nbFXulYBIpL0ayR_gDh3eu1k/QiLK0ZIrFoORdk_g2...
#  13  youtube#videoCategory  "XI7nbFXulYBIpL0ayR_gDh3eu1k/r6Ck6Z0_L0rG37VJQ...
#  14  youtube#videoCategory  "XI7nbFXulYBIpL0ayR_gDh3eu1k/EoYkczo9I3RCf96Rv...
#  15  youtube#videoCategory  "XI7nbFXulYBIpL0ayR_gDh3eu1k/w5HjcTD82G_XA3xBc...
#  16  youtube#videoCategory  "XI7nbFXulYBIpL0ayR_gDh3eu1k/lL7uWDr_071CHxifj...
#  17  youtube#videoCategory  "XI7nbFXulYBIpL0ayR_gDh3eu1k/WnuVfjO-PyFLO7NTR...
#  18  youtube#videoCategory  "XI7nbFXulYBIpL0ayR_gDh3eu1k/ctpH2hGA_UZ3volJT...
#  19  youtube#videoCategory  "XI7nbFXulYBIpL0ayR_gDh3eu1k/L0kR3-g1BAo5UD1PL...
#  20  youtube#videoCategory  "XI7nbFXulYBIpL0ayR_gDh3eu1k/pUZOAC_s9sfiwar63...
#  21  youtube#videoCategory  "XI7nbFXulYBIpL0ayR_gDh3eu1k/Xb5JLhtyNRN3AQq02...
#  22  youtube#videoCategory  "XI7nbFXulYBIpL0ayR_gDh3eu1k/u8WXzF4HIhtEi805_...
#  23  youtube#videoCategory  "XI7nbFXulYBIpL0ayR_gDh3eu1k/D04PP4Gr7wc4IV_O9...
#  24  youtube#videoCategory  "XI7nbFXulYBIpL0ayR_gDh3eu1k/i5-_AceGXQCEEMWU0...
#  25  youtube#videoCategory  "XI7nbFXulYBIpL0ayR_gDh3eu1k/rtlxd0zOixA9QHdIZ...
#  26  youtube#videoCategory  "XI7nbFXulYBIpL0ayR_gDh3eu1k/N1TrDFLRppxZgBowC...
#  27  youtube#videoCategory  "XI7nbFXulYBIpL0ayR_gDh3eu1k/7UMGi6zRySqXopr_r...
#  28  youtube#videoCategory  "XI7nbFXulYBIpL0ayR_gDh3eu1k/RScXhi324h8usyIet...
#  29  youtube#videoCategory  "XI7nbFXulYBIpL0ayR_gDh3eu1k/0n9MJVCDLpA8q7aiG...
#  30  youtube#videoCategory  "XI7nbFXulYBIpL0ayR_gDh3eu1k/x5NxSf5fz8hn4loSN...
#
#      id         snippet.channelId         snippet.title  snippet.assignable
#  0    1  UCBR8-60-B28hp2BmDPdntcQ      Film & Animation                True
#  1    2  UCBR8-60-B28hp2BmDPdntcQ      Autos & Vehicles                True
#  2   10  UCBR8-60-B28hp2BmDPdntcQ                 Music                True
#  3   15  UCBR8-60-B28hp2BmDPdntcQ        Pets & Animals                True
#  4   17  UCBR8-60-B28hp2BmDPdntcQ                Sports                True
#  5   18  UCBR8-60-B28hp2BmDPdntcQ          Short Movies               False
#  6   19  UCBR8-60-B28hp2BmDPdntcQ       Travel & Events                True
#  7   20  UCBR8-60-B28hp2BmDPdntcQ                Gaming                True
#  8   21  UCBR8-60-B28hp2BmDPdntcQ         Videoblogging               False
#  9   22  UCBR8-60-B28hp2BmDPdntcQ        People & Blogs                True
#  10  23  UCBR8-60-B28hp2BmDPdntcQ                Comedy                True
#  11  24  UCBR8-60-B28hp2BmDPdntcQ         Entertainment                True
#  12  25  UCBR8-60-B28hp2BmDPdntcQ       News & Politics                True
#  13  26  UCBR8-60-B28hp2BmDPdntcQ         Howto & Style                True
#  14  27  UCBR8-60-B28hp2BmDPdntcQ             Education                True
#  15  28  UCBR8-60-B28hp2BmDPdntcQ  Science & Technology                True
#  16  30  UCBR8-60-B28hp2BmDPdntcQ                Movies               False
#  17  31  UCBR8-60-B28hp2BmDPdntcQ       Anime/Animation               False
#  18  32  UCBR8-60-B28hp2BmDPdntcQ      Action/Adventure               False
#  19  33  UCBR8-60-B28hp2BmDPdntcQ              Classics               False
#  20  34  UCBR8-60-B28hp2BmDPdntcQ                Comedy               False
#  21  35  UCBR8-60-B28hp2BmDPdntcQ           Documentary               False
#  22  36  UCBR8-60-B28hp2BmDPdntcQ                 Drama               False
#  23  37  UCBR8-60-B28hp2BmDPdntcQ                Family               False
#  24  38  UCBR8-60-B28hp2BmDPdntcQ               Foreign               False
#  25  39  UCBR8-60-B28hp2BmDPdntcQ                Horror               False
#  26  40  UCBR8-60-B28hp2BmDPdntcQ        Sci-Fi/Fantasy               False
#  27  41  UCBR8-60-B28hp2BmDPdntcQ              Thriller               False
#  28  42  UCBR8-60-B28hp2BmDPdntcQ                Shorts               False
#  29  43  UCBR8-60-B28hp2BmDPdntcQ                 Shows               False
#  30  44  UCBR8-60-B28hp2BmDPdntcQ              Trailers               False  ,
#  'JP':                      kind                                               etag  \
#  0   youtube#videoCategory  "XI7nbFXulYBIpL0ayR_gDh3eu1k/Xy1mB4_yLrHy_BmKm...
#  1   youtube#videoCategory  "XI7nbFXulYBIpL0ayR_gDh3eu1k/UZ1oLIIz2dxIhO45Z...
#  2   youtube#videoCategory  "XI7nbFXulYBIpL0ayR_gDh3eu1k/nqRIq97-xe5XRZTxb...
#  3   youtube#videoCategory  "XI7nbFXulYBIpL0ayR_gDh3eu1k/HwXKamM1Q20q9BN-o...
#  4   youtube#videoCategory  "XI7nbFXulYBIpL0ayR_gDh3eu1k/9GQMSRjrZdHeb1OEM...
#  5   youtube#videoCategory  "XI7nbFXulYBIpL0ayR_gDh3eu1k/FJwVpGCVZ1yiJrqZb...
#  6   youtube#videoCategory  "XI7nbFXulYBIpL0ayR_gDh3eu1k/M-3iD9dwK7YJCafRf...
#  7   youtube#videoCategory  "XI7nbFXulYBIpL0ayR_gDh3eu1k/WmA0qYEfjWsAoyJFS...
#  8   youtube#videoCategory  "XI7nbFXulYBIpL0ayR_gDh3eu1k/EapFaGYG7K0StIXVf...
#  9   youtube#videoCategory  "XI7nbFXulYBIpL0ayR_gDh3eu1k/xId8RX7vRN8rqkbYZ...
#  10  youtube#videoCategory  "XI7nbFXulYBIpL0ayR_gDh3eu1k/G9LHzQmx44rX2S5ya...
#  11  youtube#videoCategory  "XI7nbFXulYBIpL0ayR_gDh3eu1k/UVB9oxX2Bvqa_w_y3...
#  12  youtube#videoCategory  "XI7nbFXulYBIpL0ayR_gDh3eu1k/QiLK0ZIrFoORdk_g2...
#  13  youtube#videoCategory  "XI7nbFXulYBIpL0ayR_gDh3eu1k/r6Ck6Z0_L0rG37VJQ...
#  14  youtube#videoCategory  "XI7nbFXulYBIpL0ayR_gDh3eu1k/EoYkczo9I3RCf96Rv...
#  15  youtube#videoCategory  "XI7nbFXulYBIpL0ayR_gDh3eu1k/w5HjcTD82G_XA3xBc...
#  16  youtube#videoCategory  "XI7nbFXulYBIpL0ayR_gDh3eu1k/lL7uWDr_071CHxifj...
#  17  youtube#videoCategory  "XI7nbFXulYBIpL0ayR_gDh3eu1k/WnuVfjO-PyFLO7NTR...
#  18  youtube#videoCategory  "XI7nbFXulYBIpL0ayR_gDh3eu1k/ctpH2hGA_UZ3volJT...
#  19  youtube#videoCategory  "XI7nbFXulYBIpL0ayR_gDh3eu1k/L0kR3-g1BAo5UD1PL...
#  20  youtube#videoCategory  "XI7nbFXulYBIpL0ayR_gDh3eu1k/pUZOAC_s9sfiwar63...
#  21  youtube#videoCategory  "XI7nbFXulYBIpL0ayR_gDh3eu1k/Xb5JLhtyNRN3AQq02...
#  22  youtube#videoCategory  "XI7nbFXulYBIpL0ayR_gDh3eu1k/u8WXzF4HIhtEi805_...
#  23  youtube#videoCategory  "XI7nbFXulYBIpL0ayR_gDh3eu1k/D04PP4Gr7wc4IV_O9...
#  24  youtube#videoCategory  "XI7nbFXulYBIpL0ayR_gDh3eu1k/i5-_AceGXQCEEMWU0...
#  25  youtube#videoCategory  "XI7nbFXulYBIpL0ayR_gDh3eu1k/rtlxd0zOixA9QHdIZ...
#  26  youtube#videoCategory  "XI7nbFXulYBIpL0ayR_gDh3eu1k/N1TrDFLRppxZgBowC...
#  27  youtube#videoCategory  "XI7nbFXulYBIpL0ayR_gDh3eu1k/7UMGi6zRySqXopr_r...
#  28  youtube#videoCategory  "XI7nbFXulYBIpL0ayR_gDh3eu1k/RScXhi324h8usyIet...
#  29  youtube#videoCategory  "XI7nbFXulYBIpL0ayR_gDh3eu1k/0n9MJVCDLpA8q7aiG...
#  30  youtube#videoCategory  "XI7nbFXulYBIpL0ayR_gDh3eu1k/x5NxSf5fz8hn4loSN...
#
#      id         snippet.channelId         snippet.title  snippet.assignable
#  0    1  UCBR8-60-B28hp2BmDPdntcQ      Film & Animation                True
#  1    2  UCBR8-60-B28hp2BmDPdntcQ      Autos & Vehicles                True
#  2   10  UCBR8-60-B28hp2BmDPdntcQ                 Music                True
#  3   15  UCBR8-60-B28hp2BmDPdntcQ        Pets & Animals                True
#  4   17  UCBR8-60-B28hp2BmDPdntcQ                Sports                True
#  5   18  UCBR8-60-B28hp2BmDPdntcQ          Short Movies               False
#  6   19  UCBR8-60-B28hp2BmDPdntcQ       Travel & Events                True
#  7   20  UCBR8-60-B28hp2BmDPdntcQ                Gaming                True
#  8   21  UCBR8-60-B28hp2BmDPdntcQ         Videoblogging               False
#  9   22  UCBR8-60-B28hp2BmDPdntcQ        People & Blogs                True
#  10  23  UCBR8-60-B28hp2BmDPdntcQ                Comedy                True
#  11  24  UCBR8-60-B28hp2BmDPdntcQ         Entertainment                True
#  12  25  UCBR8-60-B28hp2BmDPdntcQ       News & Politics                True
#  13  26  UCBR8-60-B28hp2BmDPdntcQ         Howto & Style                True
#  14  27  UCBR8-60-B28hp2BmDPdntcQ             Education                True
#  15  28  UCBR8-60-B28hp2BmDPdntcQ  Science & Technology                True
#  16  30  UCBR8-60-B28hp2BmDPdntcQ                Movies               False
#  17  31  UCBR8-60-B28hp2BmDPdntcQ       Anime/Animation               False
#  18  32  UCBR8-60-B28hp2BmDPdntcQ      Action/Adventure               False
#  19  33  UCBR8-60-B28hp2BmDPdntcQ              Classics               False
#  20  34  UCBR8-60-B28hp2BmDPdntcQ                Comedy               False
#  21  35  UCBR8-60-B28hp2BmDPdntcQ           Documentary               False
#  22  36  UCBR8-60-B28hp2BmDPdntcQ                 Drama               False
#  23  37  UCBR8-60-B28hp2BmDPdntcQ                Family               False
#  24  38  UCBR8-60-B28hp2BmDPdntcQ               Foreign               False
#  25  39  UCBR8-60-B28hp2BmDPdntcQ                Horror               False
#  26  40  UCBR8-60-B28hp2BmDPdntcQ        Sci-Fi/Fantasy               False
#  27  41  UCBR8-60-B28hp2BmDPdntcQ              Thriller               False
#  28  42  UCBR8-60-B28hp2BmDPdntcQ                Shorts               False
#  29  43  UCBR8-60-B28hp2BmDPdntcQ                 Shows               False
#  30  44  UCBR8-60-B28hp2BmDPdntcQ              Trailers               False  ,
#  'KR':                      kind                                               etag  \
#  0   youtube#videoCategory  "XI7nbFXulYBIpL0ayR_gDh3eu1k/Xy1mB4_yLrHy_BmKm...
#  1   youtube#videoCategory  "XI7nbFXulYBIpL0ayR_gDh3eu1k/UZ1oLIIz2dxIhO45Z...
#  2   youtube#videoCategory  "XI7nbFXulYBIpL0ayR_gDh3eu1k/nqRIq97-xe5XRZTxb...
#  3   youtube#videoCategory  "XI7nbFXulYBIpL0ayR_gDh3eu1k/HwXKamM1Q20q9BN-o...
#  4   youtube#videoCategory  "XI7nbFXulYBIpL0ayR_gDh3eu1k/9GQMSRjrZdHeb1OEM...
#  5   youtube#videoCategory  "XI7nbFXulYBIpL0ayR_gDh3eu1k/FJwVpGCVZ1yiJrqZb...
#  6   youtube#videoCategory  "XI7nbFXulYBIpL0ayR_gDh3eu1k/M-3iD9dwK7YJCafRf...
#  7   youtube#videoCategory  "XI7nbFXulYBIpL0ayR_gDh3eu1k/WmA0qYEfjWsAoyJFS...
#  8   youtube#videoCategory  "XI7nbFXulYBIpL0ayR_gDh3eu1k/EapFaGYG7K0StIXVf...
#  9   youtube#videoCategory  "XI7nbFXulYBIpL0ayR_gDh3eu1k/xId8RX7vRN8rqkbYZ...
#  10  youtube#videoCategory  "XI7nbFXulYBIpL0ayR_gDh3eu1k/G9LHzQmx44rX2S5ya...
#  11  youtube#videoCategory  "XI7nbFXulYBIpL0ayR_gDh3eu1k/UVB9oxX2Bvqa_w_y3...
#  12  youtube#videoCategory  "XI7nbFXulYBIpL0ayR_gDh3eu1k/QiLK0ZIrFoORdk_g2...
#  13  youtube#videoCategory  "XI7nbFXulYBIpL0ayR_gDh3eu1k/r6Ck6Z0_L0rG37VJQ...
#  14  youtube#videoCategory  "XI7nbFXulYBIpL0ayR_gDh3eu1k/EoYkczo9I3RCf96Rv...
#  15  youtube#videoCategory  "XI7nbFXulYBIpL0ayR_gDh3eu1k/w5HjcTD82G_XA3xBc...
#  16  youtube#videoCategory  "XI7nbFXulYBIpL0ayR_gDh3eu1k/lL7uWDr_071CHxifj...
#  17  youtube#videoCategory  "XI7nbFXulYBIpL0ayR_gDh3eu1k/WnuVfjO-PyFLO7NTR...
#  18  youtube#videoCategory  "XI7nbFXulYBIpL0ayR_gDh3eu1k/ctpH2hGA_UZ3volJT...
#  19  youtube#videoCategory  "XI7nbFXulYBIpL0ayR_gDh3eu1k/L0kR3-g1BAo5UD1PL...
#  20  youtube#videoCategory  "XI7nbFXulYBIpL0ayR_gDh3eu1k/pUZOAC_s9sfiwar63...
#  21  youtube#videoCategory  "XI7nbFXulYBIpL0ayR_gDh3eu1k/Xb5JLhtyNRN3AQq02...
#  22  youtube#videoCategory  "XI7nbFXulYBIpL0ayR_gDh3eu1k/u8WXzF4HIhtEi805_...
#  23  youtube#videoCategory  "XI7nbFXulYBIpL0ayR_gDh3eu1k/D04PP4Gr7wc4IV_O9...
#  24  youtube#videoCategory  "XI7nbFXulYBIpL0ayR_gDh3eu1k/i5-_AceGXQCEEMWU0...
#  25  youtube#videoCategory  "XI7nbFXulYBIpL0ayR_gDh3eu1k/rtlxd0zOixA9QHdIZ...
#  26  youtube#videoCategory  "XI7nbFXulYBIpL0ayR_gDh3eu1k/N1TrDFLRppxZgBowC...
#  27  youtube#videoCategory  "XI7nbFXulYBIpL0ayR_gDh3eu1k/7UMGi6zRySqXopr_r...
#  28  youtube#videoCategory  "XI7nbFXulYBIpL0ayR_gDh3eu1k/RScXhi324h8usyIet...
#  29  youtube#videoCategory  "XI7nbFXulYBIpL0ayR_gDh3eu1k/0n9MJVCDLpA8q7aiG...
#  30  youtube#videoCategory  "XI7nbFXulYBIpL0ayR_gDh3eu1k/x5NxSf5fz8hn4loSN...
#
#      id         snippet.channelId         snippet.title  snippet.assignable
#  0    1  UCBR8-60-B28hp2BmDPdntcQ      Film & Animation                True
#  1    2  UCBR8-60-B28hp2BmDPdntcQ      Autos & Vehicles                True
#  2   10  UCBR8-60-B28hp2BmDPdntcQ                 Music                True
#  3   15  UCBR8-60-B28hp2BmDPdntcQ        Pets & Animals                True
#  4   17  UCBR8-60-B28hp2BmDPdntcQ                Sports                True
#  5   18  UCBR8-60-B28hp2BmDPdntcQ          Short Movies               False
#  6   19  UCBR8-60-B28hp2BmDPdntcQ       Travel & Events                True
#  7   20  UCBR8-60-B28hp2BmDPdntcQ                Gaming                True
#  8   21  UCBR8-60-B28hp2BmDPdntcQ         Videoblogging               False
#  9   22  UCBR8-60-B28hp2BmDPdntcQ        People & Blogs                True
#  10  23  UCBR8-60-B28hp2BmDPdntcQ                Comedy                True
#  11  24  UCBR8-60-B28hp2BmDPdntcQ         Entertainment                True
#  12  25  UCBR8-60-B28hp2BmDPdntcQ       News & Politics                True
#  13  26  UCBR8-60-B28hp2BmDPdntcQ         Howto & Style                True
#  14  27  UCBR8-60-B28hp2BmDPdntcQ             Education                True
#  15  28  UCBR8-60-B28hp2BmDPdntcQ  Science & Technology                True
#  16  30  UCBR8-60-B28hp2BmDPdntcQ                Movies               False
#  17  31  UCBR8-60-B28hp2BmDPdntcQ       Anime/Animation               False
#  18  32  UCBR8-60-B28hp2BmDPdntcQ      Action/Adventure               False
#  19  33  UCBR8-60-B28hp2BmDPdntcQ              Classics               False
#  20  34  UCBR8-60-B28hp2BmDPdntcQ                Comedy               False
#  21  35  UCBR8-60-B28hp2BmDPdntcQ           Documentary               False
#  22  36  UCBR8-60-B28hp2BmDPdntcQ                 Drama               False
#  23  37  UCBR8-60-B28hp2BmDPdntcQ                Family               False
#  24  38  UCBR8-60-B28hp2BmDPdntcQ               Foreign               False
#  25  39  UCBR8-60-B28hp2BmDPdntcQ                Horror               False
#  26  40  UCBR8-60-B28hp2BmDPdntcQ        Sci-Fi/Fantasy               False
#  27  41  UCBR8-60-B28hp2BmDPdntcQ              Thriller               False
#  28  42  UCBR8-60-B28hp2BmDPdntcQ                Shorts               False
#  29  43  UCBR8-60-B28hp2BmDPdntcQ                 Shows               False
#  30  44  UCBR8-60-B28hp2BmDPdntcQ              Trailers               False  ,
#  'MX':                      kind                                               etag  \
#  0   youtube#videoCategory  "XI7nbFXulYBIpL0ayR_gDh3eu1k/Xy1mB4_yLrHy_BmKm...
#  1   youtube#videoCategory  "XI7nbFXulYBIpL0ayR_gDh3eu1k/UZ1oLIIz2dxIhO45Z...
#  2   youtube#videoCategory  "XI7nbFXulYBIpL0ayR_gDh3eu1k/nqRIq97-xe5XRZTxb...
#  3   youtube#videoCategory  "XI7nbFXulYBIpL0ayR_gDh3eu1k/HwXKamM1Q20q9BN-o...
#  4   youtube#videoCategory  "XI7nbFXulYBIpL0ayR_gDh3eu1k/9GQMSRjrZdHeb1OEM...
#  5   youtube#videoCategory  "XI7nbFXulYBIpL0ayR_gDh3eu1k/FJwVpGCVZ1yiJrqZb...
#  6   youtube#videoCategory  "XI7nbFXulYBIpL0ayR_gDh3eu1k/M-3iD9dwK7YJCafRf...
#  7   youtube#videoCategory  "XI7nbFXulYBIpL0ayR_gDh3eu1k/WmA0qYEfjWsAoyJFS...
#  8   youtube#videoCategory  "XI7nbFXulYBIpL0ayR_gDh3eu1k/EapFaGYG7K0StIXVf...
#  9   youtube#videoCategory  "XI7nbFXulYBIpL0ayR_gDh3eu1k/xId8RX7vRN8rqkbYZ...
#  10  youtube#videoCategory  "XI7nbFXulYBIpL0ayR_gDh3eu1k/G9LHzQmx44rX2S5ya...
#  11  youtube#videoCategory  "XI7nbFXulYBIpL0ayR_gDh3eu1k/UVB9oxX2Bvqa_w_y3...
#  12  youtube#videoCategory  "XI7nbFXulYBIpL0ayR_gDh3eu1k/QiLK0ZIrFoORdk_g2...
#  13  youtube#videoCategory  "XI7nbFXulYBIpL0ayR_gDh3eu1k/r6Ck6Z0_L0rG37VJQ...
#  14  youtube#videoCategory  "XI7nbFXulYBIpL0ayR_gDh3eu1k/EoYkczo9I3RCf96Rv...
#  15  youtube#videoCategory  "XI7nbFXulYBIpL0ayR_gDh3eu1k/w5HjcTD82G_XA3xBc...
#  16  youtube#videoCategory  "XI7nbFXulYBIpL0ayR_gDh3eu1k/lL7uWDr_071CHxifj...
#  17  youtube#videoCategory  "XI7nbFXulYBIpL0ayR_gDh3eu1k/WnuVfjO-PyFLO7NTR...
#  18  youtube#videoCategory  "XI7nbFXulYBIpL0ayR_gDh3eu1k/ctpH2hGA_UZ3volJT...
#  19  youtube#videoCategory  "XI7nbFXulYBIpL0ayR_gDh3eu1k/L0kR3-g1BAo5UD1PL...
#  20  youtube#videoCategory  "XI7nbFXulYBIpL0ayR_gDh3eu1k/pUZOAC_s9sfiwar63...
#  21  youtube#videoCategory  "XI7nbFXulYBIpL0ayR_gDh3eu1k/Xb5JLhtyNRN3AQq02...
#  22  youtube#videoCategory  "XI7nbFXulYBIpL0ayR_gDh3eu1k/u8WXzF4HIhtEi805_...
#  23  youtube#videoCategory  "XI7nbFXulYBIpL0ayR_gDh3eu1k/D04PP4Gr7wc4IV_O9...
#  24  youtube#videoCategory  "XI7nbFXulYBIpL0ayR_gDh3eu1k/i5-_AceGXQCEEMWU0...
#  25  youtube#videoCategory  "XI7nbFXulYBIpL0ayR_gDh3eu1k/rtlxd0zOixA9QHdIZ...
#  26  youtube#videoCategory  "XI7nbFXulYBIpL0ayR_gDh3eu1k/N1TrDFLRppxZgBowC...
#  27  youtube#videoCategory  "XI7nbFXulYBIpL0ayR_gDh3eu1k/7UMGi6zRySqXopr_r...
#  28  youtube#videoCategory  "XI7nbFXulYBIpL0ayR_gDh3eu1k/RScXhi324h8usyIet...
#  29  youtube#videoCategory  "XI7nbFXulYBIpL0ayR_gDh3eu1k/0n9MJVCDLpA8q7aiG...
#  30  youtube#videoCategory  "XI7nbFXulYBIpL0ayR_gDh3eu1k/x5NxSf5fz8hn4loSN...
#
#      id         snippet.channelId         snippet.title  snippet.assignable
#  0    1  UCBR8-60-B28hp2BmDPdntcQ      Film & Animation                True
#  1    2  UCBR8-60-B28hp2BmDPdntcQ      Autos & Vehicles                True
#  2   10  UCBR8-60-B28hp2BmDPdntcQ                 Music                True
#  3   15  UCBR8-60-B28hp2BmDPdntcQ        Pets & Animals                True
#  4   17  UCBR8-60-B28hp2BmDPdntcQ                Sports                True
#  5   18  UCBR8-60-B28hp2BmDPdntcQ          Short Movies               False
#  6   19  UCBR8-60-B28hp2BmDPdntcQ       Travel & Events                True
#  7   20  UCBR8-60-B28hp2BmDPdntcQ                Gaming                True
#  8   21  UCBR8-60-B28hp2BmDPdntcQ         Videoblogging               False
#  9   22  UCBR8-60-B28hp2BmDPdntcQ        People & Blogs                True
#  10  23  UCBR8-60-B28hp2BmDPdntcQ                Comedy                True
#  11  24  UCBR8-60-B28hp2BmDPdntcQ         Entertainment                True
#  12  25  UCBR8-60-B28hp2BmDPdntcQ       News & Politics                True
#  13  26  UCBR8-60-B28hp2BmDPdntcQ         Howto & Style                True
#  14  27  UCBR8-60-B28hp2BmDPdntcQ             Education                True
#  15  28  UCBR8-60-B28hp2BmDPdntcQ  Science & Technology                True
#  16  30  UCBR8-60-B28hp2BmDPdntcQ                Movies               False
#  17  31  UCBR8-60-B28hp2BmDPdntcQ       Anime/Animation               False
#  18  32  UCBR8-60-B28hp2BmDPdntcQ      Action/Adventure               False
#  19  33  UCBR8-60-B28hp2BmDPdntcQ              Classics               False
#  20  34  UCBR8-60-B28hp2BmDPdntcQ                Comedy               False
#  21  35  UCBR8-60-B28hp2BmDPdntcQ           Documentary               False
#  22  36  UCBR8-60-B28hp2BmDPdntcQ                 Drama               False
#  23  37  UCBR8-60-B28hp2BmDPdntcQ                Family               False
#  24  38  UCBR8-60-B28hp2BmDPdntcQ               Foreign               False
#  25  39  UCBR8-60-B28hp2BmDPdntcQ                Horror               False
#  26  40  UCBR8-60-B28hp2BmDPdntcQ        Sci-Fi/Fantasy               False
#  27  41  UCBR8-60-B28hp2BmDPdntcQ              Thriller               False
#  28  42  UCBR8-60-B28hp2BmDPdntcQ                Shorts               False
#  29  43  UCBR8-60-B28hp2BmDPdntcQ                 Shows               False
#  30  44  UCBR8-60-B28hp2BmDPdntcQ              Trailers               False  ,
#  'RU':                      kind                                               etag  \
#  0   youtube#videoCategory  "XI7nbFXulYBIpL0ayR_gDh3eu1k/Xy1mB4_yLrHy_BmKm...
#  1   youtube#videoCategory  "XI7nbFXulYBIpL0ayR_gDh3eu1k/UZ1oLIIz2dxIhO45Z...
#  2   youtube#videoCategory  "XI7nbFXulYBIpL0ayR_gDh3eu1k/nqRIq97-xe5XRZTxb...
#  3   youtube#videoCategory  "XI7nbFXulYBIpL0ayR_gDh3eu1k/HwXKamM1Q20q9BN-o...
#  4   youtube#videoCategory  "XI7nbFXulYBIpL0ayR_gDh3eu1k/9GQMSRjrZdHeb1OEM...
#  5   youtube#videoCategory  "XI7nbFXulYBIpL0ayR_gDh3eu1k/FJwVpGCVZ1yiJrqZb...
#  6   youtube#videoCategory  "XI7nbFXulYBIpL0ayR_gDh3eu1k/M-3iD9dwK7YJCafRf...
#  7   youtube#videoCategory  "XI7nbFXulYBIpL0ayR_gDh3eu1k/WmA0qYEfjWsAoyJFS...
#  8   youtube#videoCategory  "XI7nbFXulYBIpL0ayR_gDh3eu1k/EapFaGYG7K0StIXVf...
#  9   youtube#videoCategory  "XI7nbFXulYBIpL0ayR_gDh3eu1k/xId8RX7vRN8rqkbYZ...
#  10  youtube#videoCategory  "XI7nbFXulYBIpL0ayR_gDh3eu1k/G9LHzQmx44rX2S5ya...
#  11  youtube#videoCategory  "XI7nbFXulYBIpL0ayR_gDh3eu1k/UVB9oxX2Bvqa_w_y3...
#  12  youtube#videoCategory  "XI7nbFXulYBIpL0ayR_gDh3eu1k/QiLK0ZIrFoORdk_g2...
#  13  youtube#videoCategory  "XI7nbFXulYBIpL0ayR_gDh3eu1k/r6Ck6Z0_L0rG37VJQ...
#  14  youtube#videoCategory  "XI7nbFXulYBIpL0ayR_gDh3eu1k/EoYkczo9I3RCf96Rv...
#  15  youtube#videoCategory  "XI7nbFXulYBIpL0ayR_gDh3eu1k/w5HjcTD82G_XA3xBc...
#  16  youtube#videoCategory  "XI7nbFXulYBIpL0ayR_gDh3eu1k/lL7uWDr_071CHxifj...
#  17  youtube#videoCategory  "XI7nbFXulYBIpL0ayR_gDh3eu1k/WnuVfjO-PyFLO7NTR...
#  18  youtube#videoCategory  "XI7nbFXulYBIpL0ayR_gDh3eu1k/ctpH2hGA_UZ3volJT...
#  19  youtube#videoCategory  "XI7nbFXulYBIpL0ayR_gDh3eu1k/L0kR3-g1BAo5UD1PL...
#  20  youtube#videoCategory  "XI7nbFXulYBIpL0ayR_gDh3eu1k/pUZOAC_s9sfiwar63...
#  21  youtube#videoCategory  "XI7nbFXulYBIpL0ayR_gDh3eu1k/Xb5JLhtyNRN3AQq02...
#  22  youtube#videoCategory  "XI7nbFXulYBIpL0ayR_gDh3eu1k/u8WXzF4HIhtEi805_...
#  23  youtube#videoCategory  "XI7nbFXulYBIpL0ayR_gDh3eu1k/D04PP4Gr7wc4IV_O9...
#  24  youtube#videoCategory  "XI7nbFXulYBIpL0ayR_gDh3eu1k/i5-_AceGXQCEEMWU0...
#  25  youtube#videoCategory  "XI7nbFXulYBIpL0ayR_gDh3eu1k/rtlxd0zOixA9QHdIZ...
#  26  youtube#videoCategory  "XI7nbFXulYBIpL0ayR_gDh3eu1k/N1TrDFLRppxZgBowC...
#  27  youtube#videoCategory  "XI7nbFXulYBIpL0ayR_gDh3eu1k/7UMGi6zRySqXopr_r...
#  28  youtube#videoCategory  "XI7nbFXulYBIpL0ayR_gDh3eu1k/RScXhi324h8usyIet...
#  29  youtube#videoCategory  "XI7nbFXulYBIpL0ayR_gDh3eu1k/0n9MJVCDLpA8q7aiG...
#  30  youtube#videoCategory  "XI7nbFXulYBIpL0ayR_gDh3eu1k/x5NxSf5fz8hn4loSN...
#
#      id         snippet.channelId         snippet.title  snippet.assignable
#  0    1  UCBR8-60-B28hp2BmDPdntcQ      Film & Animation                True
#  1    2  UCBR8-60-B28hp2BmDPdntcQ      Autos & Vehicles                True
#  2   10  UCBR8-60-B28hp2BmDPdntcQ                 Music                True
#  3   15  UCBR8-60-B28hp2BmDPdntcQ        Pets & Animals                True
#  4   17  UCBR8-60-B28hp2BmDPdntcQ                Sports                True
#  5   18  UCBR8-60-B28hp2BmDPdntcQ          Short Movies               False
#  6   19  UCBR8-60-B28hp2BmDPdntcQ       Travel & Events                True
#  7   20  UCBR8-60-B28hp2BmDPdntcQ                Gaming                True
#  8   21  UCBR8-60-B28hp2BmDPdntcQ         Videoblogging               False
#  9   22  UCBR8-60-B28hp2BmDPdntcQ        People & Blogs                True
#  10  23  UCBR8-60-B28hp2BmDPdntcQ                Comedy                True
#  11  24  UCBR8-60-B28hp2BmDPdntcQ         Entertainment                True
#  12  25  UCBR8-60-B28hp2BmDPdntcQ       News & Politics                True
#  13  26  UCBR8-60-B28hp2BmDPdntcQ         Howto & Style                True
#  14  27  UCBR8-60-B28hp2BmDPdntcQ             Education                True
#  15  28  UCBR8-60-B28hp2BmDPdntcQ  Science & Technology                True
#  16  30  UCBR8-60-B28hp2BmDPdntcQ                Movies               False
#  17  31  UCBR8-60-B28hp2BmDPdntcQ       Anime/Animation               False
#  18  32  UCBR8-60-B28hp2BmDPdntcQ      Action/Adventure               False
#  19  33  UCBR8-60-B28hp2BmDPdntcQ              Classics               False
#  20  34  UCBR8-60-B28hp2BmDPdntcQ                Comedy               False
#  21  35  UCBR8-60-B28hp2BmDPdntcQ           Documentary               False
#  22  36  UCBR8-60-B28hp2BmDPdntcQ                 Drama               False
#  23  37  UCBR8-60-B28hp2BmDPdntcQ                Family               False
#  24  38  UCBR8-60-B28hp2BmDPdntcQ               Foreign               False
#  25  39  UCBR8-60-B28hp2BmDPdntcQ                Horror               False
#  26  40  UCBR8-60-B28hp2BmDPdntcQ        Sci-Fi/Fantasy               False
#  27  41  UCBR8-60-B28hp2BmDPdntcQ              Thriller               False
#  28  42  UCBR8-60-B28hp2BmDPdntcQ                Shorts               False
#  29  43  UCBR8-60-B28hp2BmDPdntcQ                 Shows               False
#  30  44  UCBR8-60-B28hp2BmDPdntcQ              Trailers               False  ,
#  'US':                      kind                                               etag  \
#  0   youtube#videoCategory  "m2yskBQFythfE4irbTIeOgYYfBU/Xy1mB4_yLrHy_BmKm...
#  1   youtube#videoCategory  "m2yskBQFythfE4irbTIeOgYYfBU/UZ1oLIIz2dxIhO45Z...
#  2   youtube#videoCategory  "m2yskBQFythfE4irbTIeOgYYfBU/nqRIq97-xe5XRZTxb...
#  3   youtube#videoCategory  "m2yskBQFythfE4irbTIeOgYYfBU/HwXKamM1Q20q9BN-o...
#  4   youtube#videoCategory  "m2yskBQFythfE4irbTIeOgYYfBU/9GQMSRjrZdHeb1OEM...
#  5   youtube#videoCategory  "m2yskBQFythfE4irbTIeOgYYfBU/FJwVpGCVZ1yiJrqZb...
#  6   youtube#videoCategory  "m2yskBQFythfE4irbTIeOgYYfBU/M-3iD9dwK7YJCafRf...
#  7   youtube#videoCategory  "m2yskBQFythfE4irbTIeOgYYfBU/WmA0qYEfjWsAoyJFS...
#  8   youtube#videoCategory  "m2yskBQFythfE4irbTIeOgYYfBU/EapFaGYG7K0StIXVf...
#  9   youtube#videoCategory  "m2yskBQFythfE4irbTIeOgYYfBU/xId8RX7vRN8rqkbYZ...
#  10  youtube#videoCategory  "m2yskBQFythfE4irbTIeOgYYfBU/G9LHzQmx44rX2S5ya...
#  11  youtube#videoCategory  "m2yskBQFythfE4irbTIeOgYYfBU/UVB9oxX2Bvqa_w_y3...
#  12  youtube#videoCategory  "m2yskBQFythfE4irbTIeOgYYfBU/QiLK0ZIrFoORdk_g2...
#  13  youtube#videoCategory  "m2yskBQFythfE4irbTIeOgYYfBU/r6Ck6Z0_L0rG37VJQ...
#  14  youtube#videoCategory  "m2yskBQFythfE4irbTIeOgYYfBU/EoYkczo9I3RCf96Rv...
#  15  youtube#videoCategory  "m2yskBQFythfE4irbTIeOgYYfBU/w5HjcTD82G_XA3xBc...
#  16  youtube#videoCategory  "m2yskBQFythfE4irbTIeOgYYfBU/SalkJoBWq_smSEqiA...
#  17  youtube#videoCategory  "m2yskBQFythfE4irbTIeOgYYfBU/lL7uWDr_071CHxifj...
#  18  youtube#videoCategory  "m2yskBQFythfE4irbTIeOgYYfBU/WnuVfjO-PyFLO7NTR...
#  19  youtube#videoCategory  "m2yskBQFythfE4irbTIeOgYYfBU/ctpH2hGA_UZ3volJT...
#  20  youtube#videoCategory  "m2yskBQFythfE4irbTIeOgYYfBU/L0kR3-g1BAo5UD1PL...
#  21  youtube#videoCategory  "m2yskBQFythfE4irbTIeOgYYfBU/pUZOAC_s9sfiwar63...
#  22  youtube#videoCategory  "m2yskBQFythfE4irbTIeOgYYfBU/Xb5JLhtyNRN3AQq02...
#  23  youtube#videoCategory  "m2yskBQFythfE4irbTIeOgYYfBU/u8WXzF4HIhtEi805_...
#  24  youtube#videoCategory  "m2yskBQFythfE4irbTIeOgYYfBU/D04PP4Gr7wc4IV_O9...
#  25  youtube#videoCategory  "m2yskBQFythfE4irbTIeOgYYfBU/i5-_AceGXQCEEMWU0...
#  26  youtube#videoCategory  "m2yskBQFythfE4irbTIeOgYYfBU/rtlxd0zOixA9QHdIZ...
#  27  youtube#videoCategory  "m2yskBQFythfE4irbTIeOgYYfBU/N1TrDFLRppxZgBowC...
#  28  youtube#videoCategory  "m2yskBQFythfE4irbTIeOgYYfBU/7UMGi6zRySqXopr_r...
#  29  youtube#videoCategory  "m2yskBQFythfE4irbTIeOgYYfBU/RScXhi324h8usyIet...
#  30  youtube#videoCategory  "m2yskBQFythfE4irbTIeOgYYfBU/0n9MJVCDLpA8q7aiG...
#  31  youtube#videoCategory  "m2yskBQFythfE4irbTIeOgYYfBU/x5NxSf5fz8hn4loSN...
#
#      id         snippet.channelId          snippet.title  snippet.assignable
#  0    1  UCBR8-60-B28hp2BmDPdntcQ       Film & Animation                True
#  1    2  UCBR8-60-B28hp2BmDPdntcQ       Autos & Vehicles                True
#  2   10  UCBR8-60-B28hp2BmDPdntcQ                  Music                True
#  3   15  UCBR8-60-B28hp2BmDPdntcQ         Pets & Animals                True
#  4   17  UCBR8-60-B28hp2BmDPdntcQ                 Sports                True
#  5   18  UCBR8-60-B28hp2BmDPdntcQ           Short Movies               False
#  6   19  UCBR8-60-B28hp2BmDPdntcQ        Travel & Events                True
#  7   20  UCBR8-60-B28hp2BmDPdntcQ                 Gaming                True
#  8   21  UCBR8-60-B28hp2BmDPdntcQ          Videoblogging               False
#  9   22  UCBR8-60-B28hp2BmDPdntcQ         People & Blogs                True
#  10  23  UCBR8-60-B28hp2BmDPdntcQ                 Comedy                True
#  11  24  UCBR8-60-B28hp2BmDPdntcQ          Entertainment                True
#  12  25  UCBR8-60-B28hp2BmDPdntcQ        News & Politics                True
#  13  26  UCBR8-60-B28hp2BmDPdntcQ          Howto & Style                True
#  14  27  UCBR8-60-B28hp2BmDPdntcQ              Education                True
#  15  28  UCBR8-60-B28hp2BmDPdntcQ   Science & Technology                True
#  16  29  UCBR8-60-B28hp2BmDPdntcQ  Nonprofits & Activism                True
#  17  30  UCBR8-60-B28hp2BmDPdntcQ                 Movies               False
#  18  31  UCBR8-60-B28hp2BmDPdntcQ        Anime/Animation               False
#  19  32  UCBR8-60-B28hp2BmDPdntcQ       Action/Adventure               False
#  20  33  UCBR8-60-B28hp2BmDPdntcQ               Classics               False
#  21  34  UCBR8-60-B28hp2BmDPdntcQ                 Comedy               False
#  22  35  UCBR8-60-B28hp2BmDPdntcQ            Documentary               False
#  23  36  UCBR8-60-B28hp2BmDPdntcQ                  Drama               False
#  24  37  UCBR8-60-B28hp2BmDPdntcQ                 Family               False
#  25  38  UCBR8-60-B28hp2BmDPdntcQ                Foreign               False
#  26  39  UCBR8-60-B28hp2BmDPdntcQ                 Horror               False
#  27  40  UCBR8-60-B28hp2BmDPdntcQ         Sci-Fi/Fantasy               False
#  28  41  UCBR8-60-B28hp2BmDPdntcQ               Thriller               False
#  29  42  UCBR8-60-B28hp2BmDPdntcQ                 Shorts               False
#  30  43  UCBR8-60-B28hp2BmDPdntcQ                  Shows               False
#  31  44  UCBR8-60-B28hp2BmDPdntcQ               Trailers               False  }

# %% [markdown]
# ## 15. For each country, determine how many videos have a category that is not assignable.

# %%
from pathlib import Path

# make sure output folder exists (adjust path if you want a different location)
out_dir = Path("../output")
out_dir.mkdir(parents=True, exist_ok=True)

# save the dataframe
not_assignable_df.to_csv(out_dir / "not_assignable_counts_by_country.csv", index=False)

print("Saved to:", (out_dir / "not_assignable_counts_by_country.csv").resolve())

# show result
not_assignable_df
# Out:
# Saved to: C:\Users\Lenovo\Rehman Nafay Ur - 2025-26 Project - Foundation of Computer Science\output\not_assignable_counts_by_country.csv
#   country  not_assignable_videos  total_videos
# 0      CA                     74         40881
# 1      DE                    256         40840
# 2      FR                    114         40724
# 3      GB                     90         38916
# 4      IN                    105         37352
# 5      JP                     18         20523
# 6      KR                    288         34567
# 7      MX                    252         40451
# 8      RU                   1541         40739
# 9      US                      0         40949

# %%
# Task 15: For each country, count videos whose category is NOT assignable
# (robust single cell for Jupyter)

import pandas as pd
from pathlib import Path
import json

# ---- 0. Ensure `df` exists ----
# (Assumes your main dataframe is named `df` from earlier cells.)
if 'df' not in globals():
    raise RuntimeError("DataFrame `df` not found. Run Task 1 (concatenate CSVs) first.")

# ---- 1. Load or validate `categories` mapping if not in memory ----
# `categories` may be a dict (id->title) per country, or a dict country->DataFrame.
if 'categories' not in globals():
    # try loading saved mapping from previous task
    cat_file = Path("../output/categories_mapping.json")
    if cat_file.exists():
        with open(cat_file, "r", encoding="utf-8") as fh:
            try:
                categories = json.load(fh)   # likely dict id->title (global), not per-country
            except Exception:
                categories = {}
    else:
        categories = {}

# ---- 2. Find which column in df holds the category id ----
cat_col = None
for c in df.columns:
    if "category" in c.lower():
        cat_col = c
        break

# create normalized category_id column (string, empty if missing)
if cat_col is None:
    df["category_id"] = ""
else:
    df["category_id"] = df[cat_col].where(df[cat_col].notna(), "").astype(str).str.strip()

# ---- 3. Helper: get set of assignable category ids for a given country code ----
def category_id_set_for(country_code):
    """
    Return a set of category ids (strings) known for this country.
    Handles several shapes of `categories`:
      - categories is a dict mapping country_code -> DataFrame (from Task 14)
      - categories is a dict mapping id -> title (global mapping)
    """
    # if categories is empty
    if not categories:
        return set()
    # If categories has country keys
    if isinstance(categories, dict) and country_code in categories:
        obj = categories[country_code]
        # If obj is a DataFrame-like (e.g., read via pd.json_normalize)
        if isinstance(obj, dict):
            # sometimes json.load produced nested dicts: treat keys as ids
            return set([str(k).strip() for k in obj.keys() if str(k).strip() != ""])
        try:
            # try to detect DataFrame-like (pandas object)
            import pandas as _pd
            if isinstance(obj, _pd.DataFrame):
                for cand in ["id", "categoryId", "snippet.id", "snippet.title"]:
                    if cand in obj.columns:
                        if cand == "snippet.title":
                            # titles are not ids -> no reliable ids here
                            return set()
                        return set(obj[cand].astype(str).str.strip().dropna().unique())
                # fallback: flatten values
                vals = obj.values.flatten()
                return set([str(v).strip() for v in vals if pd.notna(v) and str(v).strip() != ""])
        except Exception:
            # fallback: if obj is list-like
            try:
                return set([str(v).strip() for v in obj if v is not None and str(v).strip() != ""])
            except Exception:
                return set()
    # If categories appears to be a global id->title mapping (no country keys)
    if isinstance(categories, dict):
        # check if keys look like numeric ids or short strings (category ids)
        # return keys as ids
        return set([str(k).strip() for k in categories.keys() if str(k).strip() != ""])
    # otherwise unknown shape
    return set()

# ---- 4. Compute not-assignable counts per country ----
results = []
countries = sorted(df["country"].fillna("").astype(str).unique())

for country in countries:
    if country == "" or pd.isna(country):
        country_label = ""  # keep blank if present
    else:
        country_label = country
    sub = df[df["country"].astype(str) == country_label]
    total = len(sub)
    if total == 0:
        results.append({"country": country_label, "total_videos": 0, "not_assignable_videos": 0})
        continue
    ids_set = category_id_set_for(country_label)
    # A video is not assignable when category_id is empty or not in ids_set
    def is_not_assignable(cat):
        cat_s = "" if (cat is None or (isinstance(cat, float) and pd.isna(cat))) else str(cat).strip()
        if cat_s == "" or cat_s.lower() in ["nan", "none", "null"]:
            return True
        if not ids_set:
            # if we have no mapping for this country, treat only empty as not assignable
            return False if cat_s != "" else True
        return cat_s not in ids_set
    cnt_not = int(sub["category_id"].apply(is_not_assignable).sum())
    results.append({"country": country_label, "total_videos": int(total), "not_assignable_videos": cnt_not})

not_assignable_df = pd.DataFrame(results).sort_values("country").reset_index(drop=True)

# ---- 5. Save output (create folder if needed) and display ----
out_dir = Path("../output")
out_dir.mkdir(parents=True, exist_ok=True)
out_file = out_dir / "not_assignable_counts_by_country.csv"
not_assignable_df.to_csv(out_file, index=False)

print("Saved:", out_file.resolve())
not_assignable_df
# Out:
# Saved: C:\Users\Lenovo\Rehman Nafay Ur - 2025-26 Project - Foundation of Computer Science\output\not_assignable_counts_by_country.csv
#   country  total_videos  not_assignable_videos
# 0      CA         40881                     74
# 1      DE         40840                    256
# 2      FR         40724                    114
# 3      GB         38916                     90
# 4      IN         37352                    105
# 5      JP         20523                     18
# 6      KR         34567                    288
# 7      MX         40451                    252
# 8      RU         40739                   1541
# 9      US         40949                      0
